# %%
from elg import Service
import requests

# %%
with open('paragraphe.txt', encoding='utf-8') as f:
    text = f.read()

# %%
service = Service.from_id(8122)
# Out:
# Please go to this URL in your browser: https://live.european-language-grid.eu/auth/realms/ELG/protocol/openid-connect/auth?client_id=elg-oob&redirect_uri=urn:ietf:wg:oauth:2.0:oob&response_type=code&scope=openid

# %%
# La longueur du texte est tres grande, donc on va le diviser en phrases
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

len(sentences)
# Out:
# 9

# %%
results = []
for i,sen in enumerate(sentences):
    try:
        results.append(service(request_input=sen, request_type="text"))
    except Exception:
        print('*'*50 + str(i))
# Out:
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Une lombalgie sur cinq entraîne un arrêt de travail. - mimeType: text/plain
#
# Progress: 33.3%
# Progress: 33.3%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Elle représente 30 % des arrêts de travail de plus de 6 mois et 20 % des accidents du travail, avec des arrêts de travail d’une durée de 2 mois en moyenne. - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 33.3%
# Progress: 33.3%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Elle est ainsi devenue la 1re cause d’exclusion du travail avant 45 ans et le 3e motif d’admission en invalidité (4). - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 33.3%
# Progress: 33.3%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Un autre enjeu est de prévenir la chronicisation de la lombalgie. - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 33.3%
# Progress: 33.3%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Le terme « douleur lombaire » ne nécessite pas de définition particulière ; par contre, le terme « douleur radiculaire » est sujet à controverse. - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 33.3%
# Progress: 33.3%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Dans ce guide de pratique clinique, la douleur radiculaire est définie comme une douleur des extrémités inférieures, siégeant dans un (ou plusieurs) dermatome(s). - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 44.4%
# Progress: 44.4%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Chez certains patients, elle prédomine sur la lombalgie ; chez d’autres, elle se manifeste de façon isolée. - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 40.0%
# Progress: 40.0%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Les douleurs radiculaires ne présentent pas toutes une composante neuropathique (= douleur provoquée par une lésion du système nerveux). - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 44.4%
# Progress: 44.4%
# Progress: 100.0%
# Calling:
# 	[8122] Text to Terminological Concept System
# with request:
# 	type: text - content: Il est noté que les termes douleurs lombaires (plutôt que lombalgie), ou douleurs lombaires et radiculaires (plutôt que sciatique), sont utilisés dans la version française. - mimeType: text/plain
#
# Progress: 1.0%
# Progress: 44.4%
# Progress: 44.4%
# Progress: 100.0%
# Progress: 100.0%
# Progress: 100.0%
# Progress: 100.0%
# Progress: 100.0%
# Progress: 100.0%

# %%
len(results)
# Out:
# 9

# %%
results[0]
# Out:
# AnnotationsResponse(type='annotations', warnings=None, features={'Graph Link': 'https://live.european-language-grid.eu/temp-storage/retrieve/01hffg26-jfkfp9dbze43hp3wdgz4zggtstbga', 'TBX Link': 'https://live.european-language-grid.eu/temp-storage/retrieve/01hffg26-1cn5gqskk9mcacvzmiq4swzrm20ipc'}, annotations={'c1: lombalgie': [Annotation(start=4, end=13, source_start=None, source_end=None, features={'id': 'c1', 'term': 'lombalgie', 'relations': [{'type': 'associativeRelation', 'related concept': 'c2', 'related terms': 'arrêt de travail'}]})], 'c2: arrêt de travail': [Annotation(start=35, end=52, source_start=None, source_end=None, features={'id': 'c2', 'term': 'arrêt de travail', 'relations': []})]})

# %%
dictRest = []
for result in results:
    for item in result['annotations'].values():
        for annot in item:
            dictRest.append((annot['start'], annot['end'], annot['features']))

# %%
import json

# %%
with open("Text2TCS_parg.json", 'w', encoding="UTF-8") as f:
    f.write(json.dumps(dictRest))

# %%
with open("Text2TCS.json") as f:
    dictRest = json.loads(f.read())

# %%
dictRest[0]
# Out:
# [0,
#  10,
#  {'id': 'c01',
#   'term': 'FICHE MÉMO',
#   'relations': [{'type': 'genericRelation',
#     'related concept': 'c06',
#     'related terms': 'document'}]}]

# %%
dictRest
# Out:
# [[0,
#   10,
#   {'id': 'c01',
#    'term': 'FICHE MÉMO',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c06',
#      'related terms': 'document'}]}],
#  [270,
#   282,
#   {'id': 'c01',
#    'term': 'fiches mémo',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c06',
#      'related terms': 'document'}]}],
#  [12,
#   27,
#   {'id': 'c02',
#    'term': 'Prise en charge',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c03',
#      'related terms': 'patient présentant'}]}],
#  [31, 49, {'id': 'c03', 'term': 'patient présentant', 'relations': []}],
#  [55,
#   72,
#   {'id': 'c04',
#    'term': 'lombalgie commune',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'méthode d’élaboration'}]}],
#  [78,
#   99,
#   {'id': 'c05',
#    'term': 'RAPPORT D’ÉLABORATION',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'méthode d’élaboration'}]}],
#  [116, 124, {'id': 'c06', 'term': 'document', 'relations': []}],
#  [138,
#   162,
#   {'id': 'c07',
#    'term': 'texte de recommandations',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c06',
#      'related terms': 'document'}]}],
#  [176,
#   181,
#   {'id': 'c08',
#    'term': 'Prise',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c04',
#      'related terms': 'lombalgie commune'}]}],
#  [195,
#   202,
#   {'id': 'c09',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c08',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c04',
#      'related terms': 'lombalgie commune'}]}],
#  [241, 263, {'id': 'c10', 'term': 'méthode d’élaboration', 'relations': []}],
#  [324, 339, {'id': 'c11', 'term': 'recommandations', 'relations': []}],
#  [343,
#   356,
#   {'id': 'c12',
#    'term': 'messages-clés',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'méthode d’élaboration'},
#     {'type': 'partitiveRelation',
#      'related concept': 'c11',
#      'related terms': 'recommandations'},
#     {'type': 'propertyRelation',
#      'related concept': 'c13',
#      'related terms': 'format'}]}],
#  [405, 411, {'id': 'c13', 'term': 'format', 'relations': []}],
#  [413, 418, {'id': 'c14', 'term': 'court', 'relations': []}],
#  [4,
#   15,
#   {'id': 'c1',
#    'term': 'fiches mémo',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c2',
#      'related terms': 'qualité'},
#     {'type': 'instrumentalRelation',
#      'related concept': 'c3',
#      'related terms': 'sécurité'}]}],
#  [67,
#   74,
#   {'id': 'c2',
#    'term': 'qualité',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'sécurité'}]}],
#  [84, 92, {'id': 'c3', 'term': 'sécurité', 'relations': []}],
#  [98, 104, {'id': 'c4', 'term': 'soins', 'relations': []}],
#  [5, 17, {'id': 'c1', 'term': 'fiches mémo', 'relations': []}],
#  [49,
#   73,
#   {'id': 'c2',
#    'term': 'professionnel de santé',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'fiches mémo'}]}],
#  [98,
#   110,
#   {'id': 'c3',
#    'term': 'discernement',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'prise en charge'},
#     {'type': 'associativeRelation',
#      'related concept': 'c5',
#      'related terms': 'patient'}]}],
#  [122, 139, {'id': 'c4', 'term': 'prise en charge', 'relations': []}],
#  [145,
#   152,
#   {'id': 'c5',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'prise en charge'},
#     {'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'appropriée'},
#     {'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'constatations'}]}],
#  [203, 214, {'id': 'c6', 'term': 'appropriée', 'relations': []}],
#  [242,
#   255,
#   {'id': 'c7',
#    'term': 'constatations',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c8',
#      'related terms': 'préférences'}]}],
#  [263,
#   274,
#   {'id': 'c8',
#    'term': 'préférences',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c5',
#      'related terms': 'patient'}]}],
#  [6,
#   16,
#   {'id': 'c1',
#    'term': 'fiche mémo',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c3',
#      'related terms': 'guide méthodologique'}]}],
#  [41,
#   48,
#   {'id': 'c2',
#    'term': 'méthode',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c3',
#      'related terms': 'guide méthodologique'}]}],
#  [65, 85, {'id': 'c3', 'term': 'guide méthodologique', 'relations': []}],
#  [93,
#   96,
#   {'id': 'c4',
#    'term': 'HAS',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c5',
#      'related terms': 'site'},
#     {'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'fiches mémo'}]}],
#  [116, 120, {'id': 'c5', 'term': 'site', 'relations': []}],
#  [123,
#   144,
#   {'id': 'c6',
#    'term': 'Méthode d’élaboration',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'fiches mémo'},
#     {'type': 'activityRelation',
#      'related concept': 'c8',
#      'related terms': 'fiches pertinence'}]}],
#  [149, 160, {'id': 'c7', 'term': 'fiches mémo', 'relations': []}],
#  [168, 186, {'id': 'c8', 'term': 'fiches pertinence', 'relations': []}],
#  [0,
#   5,
#   {'id': 'c01',
#    'term': 'Grade',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c02',
#      'related terms': 'recommandations'}]}],
#  [10, 25, {'id': 'c02', 'term': 'recommandations', 'relations': []}],
#  [29,
#   56,
#   {'id': 'c03', 'term': 'Preuve scientifique établie', 'relations': []}],
#  [75,
#   81,
#   {'id': 'c04',
#    'term': 'études',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c05',
#      'related terms': 'niveau'}]}],
#  [90, 96, {'id': 'c05', 'term': 'niveau', 'relations': []}],
#  [130,
#   148,
#   {'id': 'c06',
#    'term': 'essais comparatifs',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c04',
#      'related terms': 'études'}]}],
#  [155,
#   165,
#   {'id': 'c07',
#    'term': 'randomisés',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c08',
#      'related terms': 'puissance'},
#     {'type': 'propertyRelation',
#      'related concept': 'c09',
#      'related terms': 'biais majeur'},
#     {'type': 'activityRelation',
#      'related concept': 'c10',
#      'related terms': 'méta-analyse'},
#     {'type': 'genericRelation',
#      'related concept': 'c11',
#      'related terms': 'analyse de décision'}]}],
#  [178,
#   187,
#   {'id': 'c08',
#    'term': 'puissance',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c09',
#      'related terms': 'biais majeur'}]}],
#  [199, 212, {'id': 'c09', 'term': 'biais majeur', 'relations': []}],
#  [218, 230, {'id': 'c10', 'term': 'méta-analyse', 'relations': []}],
#  [267, 286, {'id': 'c11', 'term': 'analyse de décision', 'relations': []}],
#  [0, 24, {'id': 'c01', 'term': 'Présomption scientifique', 'relations': []}],
#  [43,
#   67,
#   {'id': 'c02',
#    'term': 'présomption scientifique',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c03',
#      'related terms': 'études'}]}],
#  [84, 90, {'id': 'c03', 'term': 'études', 'relations': []}],
#  [119, 120, {'id': 'c04', 'term': 'B', 'relations': []}],
#  [124, 130, {'id': 'c05', 'term': 'preuve', 'relations': []}],
#  [163,
#   181,
#   {'id': 'c06',
#    'term': 'essais comparatifs',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c05',
#      'related terms': 'preuve'},
#     {'type': 'instrumentalRelation',
#      'related concept': 'c07',
#      'related terms': 'randomisés'}]}],
#  [182,
#   192,
#   {'id': 'c07',
#    'term': 'randomisés',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c05',
#      'related terms': 'preuve'}]}],
#  [203,
#   213,
#   {'id': 'c08',
#    'term': 'puissance',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c05',
#      'related terms': 'preuve'}]}],
#  [219,
#   238,
#   {'id': 'c09',
#    'term': 'études comparatives',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c10',
#      'related terms': 'non randomisées'}]}],
#  [239, 254, {'id': 'c10', 'term': 'non randomisées', 'relations': []}],
#  [272,
#   290,
#   {'id': 'c11',
#    'term': 'études de cohorte',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c10',
#      'related terms': 'non randomisées'}]}],
#  [7, 13, {'id': 'c1', 'term': 'niveau', 'relations': []}],
#  [17,
#   23,
#   {'id': 'c2',
#    'term': 'preuve',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c1',
#      'related terms': 'niveau'}]}],
#  [42,
#   48,
#   {'id': 'c3',
#    'term': 'études',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c1',
#      'related terms': 'niveau'}]}],
#  [88,
#   106,
#   {'id': 'c4',
#    'term': 'études cas-témoins',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c3',
#      'related terms': 'études'}]}],
#  [139,
#   161,
#   {'id': 'c5',
#    'term': 'études rétrospectives',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c7',
#      'related terms': 'études comparatives'}]}],
#  [166, 172, {'id': 'c6', 'term': 'séries', 'relations': []}],
#  [185,
#   204,
#   {'id': 'c7',
#    'term': 'études comparatives',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c6',
#      'related terms': 'séries'}]}],
#  [221, 237, {'id': 'c8', 'term': 'biais importants', 'relations': []}],
#  [0, 16, {'id': 'c1', 'term': 'Accord d’experts', 'relations': []}],
#  [47,
#   62,
#   {'id': 'c2',
#    'term': 'recommandations',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c4',
#      'related terms': 'experts'},
#     {'type': 'originationRelation',
#      'related concept': 'c5',
#      'related terms': 'groupe'}]}],
#  [83, 89, {'id': 'c3', 'term': 'accord', 'relations': []}],
#  [96,
#   103,
#   {'id': 'c4',
#    'term': 'experts',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'accord'},
#     {'type': 'originationRelation',
#      'related concept': 'c5',
#      'related terms': 'groupe'}]}],
#  [107,
#   113,
#   {'id': 'c5',
#    'term': 'groupe',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'accord'}]}],
#  [117, 132, {'id': 'c6', 'term': 'AE de travail', 'relations': []}],
#  [139,
#   151,
#   {'id': 'c7',
#    'term': 'consultation',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'AE de travail'}]}],
#  [155,
#   173,
#   {'id': 'c8',
#    'term': 'groupe de lecture',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'AE de travail'},
#     {'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'consultation'}]}],
#  [13, 22, {'id': 'c1', 'term': 'gradation', 'relations': []}],
#  [48, 63, {'id': 'c2', 'term': 'recommandations', 'relations': []}],
#  [3, 13, {'id': 'c1', 'term': 'fiche mémo', 'relations': []}],
#  [58, 81, {'id': 'c2', 'term': 'Haute Autorité de Santé', 'relations': []}],
#  [83, 104, {'id': 'c3', 'term': 'Service communication', 'relations': []}],
#  [124,
#   149,
#   {'id': 'c4', 'term': 'avenue du Stade de France', 'relations': []}],
#  [160, 181, {'id': 'c5', 'term': 'Saint-Denis La Plaine', 'relations': []}],
#  [56, 64, {'id': 'c1', 'term': 'document', 'relations': []}],
#  [71,
#   77,
#   {'id': 'c2',
#    'term': 'adopté',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'document'}]}],
#  [85,
#   122,
#   {'id': 'c3',
#    'term': 'Collège de la Haute Autorité de Santé',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'document'},
#     {'type': 'activityRelation',
#      'related concept': 'c2',
#      'related terms': 'adopté'}]}],
#  [2, 25, {'id': 'c1', 'term': 'Haute Autorité de Santé', 'relations': []}],
#  [36,
#   39,
#   {'id': 'c2',
#    'term': 'HAS',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'Service des bonnes pratiques professionnelles'}]}],
#  [42,
#   87,
#   {'id': 'c3',
#    'term': 'Service des bonnes pratiques professionnelles',
#    'relations': []}],
#  [105,
#   110,
#   {'id': 'c4',
#    'term': 'Prise',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'lombalgie commune'}]}],
#  [124,
#   131,
#   {'id': 'c5',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c6',
#      'related terms': 'lombalgie commune'}]}],
#  [147, 164, {'id': 'c6', 'term': 'lombalgie commune', 'relations': []}],
#  [166, 184, {'id': 'c7', 'term': 'Table des matières', 'relations': []}],
#  [186, 198, {'id': 'c8', 'term': 'Abréviations', 'relations': []}],
#  [202,
#   211,
#   {'id': 'c9',
#    'term': 'acronymes',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c8',
#      'related terms': 'Abréviations'}]}],
#  [0,
#   7,
#   {'id': 'c01',
#    'term': 'Données',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c02',
#      'related terms': 'recherche documentaire'}]}],
#  [21,
#   43,
#   {'id': 'c02',
#    'term': 'recherche documentaire',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c13',
#      'related terms': 'recherche'}]}],
#  [118, 134, {'id': 'c03', 'term': 'Caractéristiques', 'relations': []}],
#  [135, 150, {'id': 'c04', 'term': 'méthodologiques', 'relations': []}],
#  [167,
#   182,
#   {'id': 'c05',
#    'term': 'recommandations',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c03',
#      'related terms': 'Caractéristiques'},
#     {'type': 'propertyRelation',
#      'related concept': 'c04',
#      'related terms': 'méthodologiques'}]}],
#  [361,
#   371,
#   {'id': 'c06',
#    'term': 'Définition',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c07',
#      'related terms': 'lombalgie commune'}]}],
#  [541,
#   551,
#   {'id': 'c06',
#    'term': 'définition',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c07',
#      'related terms': 'lombalgie commune'}]}],
#  [378,
#   395,
#   {'id': 'c07',
#    'term': 'lombalgie commune',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c12',
#      'related terms': 'douleur lombaire'}]}],
#  [495,
#   501,
#   {'id': 'c08',
#    'term': 'Pistes',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'Définition; définition'},
#     {'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'lombalgie commune'},
#     {'type': 'associativeRelation',
#      'related concept': 'c22',
#      'related terms': 'non médicamenteuses'}]}],
#  [1852,
#   1858,
#   {'id': 'c08',
#    'term': 'Prises',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'Définition; définition'},
#     {'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'lombalgie commune'},
#     {'type': 'associativeRelation',
#      'related concept': 'c22',
#      'related terms': 'non médicamenteuses'}]}],
#  [621,
#   636,
#   {'id': 'c09',
#    'term': 'Prise en charge',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'Pistes; Prises'},
#     {'type': 'associativeRelation',
#      'related concept': 'c10',
#      'related terms': 'patient lombalgique'},
#     {'type': 'associativeRelation',
#      'related concept': 'c19',
#      'related terms': 'médicamenteuse'}]}],
#  [648, 667, {'id': 'c10', 'term': 'patient lombalgique', 'relations': []}],
#  [754,
#   773,
#   {'id': 'c11',
#    'term': 'Évaluation clinique',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c16',
#      'related terms': 'Évaluation'},
#     {'type': 'instrumentalRelation',
#      'related concept': 'c13',
#      'related terms': 'recherche'},
#     {'type': 'activityRelation',
#      'related concept': 'c14',
#      'related terms': 'drapeaux'}]}],
#  [780,
#   796,
#   {'id': 'c12',
#    'term': 'douleur lombaire',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'Pistes; Prises'},
#     {'type': 'associativeRelation',
#      'related concept': 'c14',
#      'related terms': 'drapeaux'}]}],
#  [799,
#   808,
#   {'id': 'c13',
#    'term': 'recherche',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c14',
#      'related terms': 'drapeaux'}]}],
#  [823, 831, {'id': 'c14', 'term': 'drapeaux', 'relations': []}],
#  [833,
#   839,
#   {'id': 'c15',
#    'term': 'rouges',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'Pistes; Prises'}]}],
#  [991,
#   1001,
#   {'id': 'c16',
#    'term': 'Évaluation',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c17',
#      'related terms': 'risque'}]}],
#  [1005, 1011, {'id': 'c17', 'term': 'risque', 'relations': []}],
#  [1133,
#   1143,
#   {'id': 'c18',
#    'term': 'Pertinence',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c16',
#      'related terms': 'Évaluation'}]}],
#  [1297, 1311, {'id': 'c19', 'term': 'médicamenteuse', 'relations': []}],
#  [1554,
#   1580,
#   {'id': 'c20', 'term': 'Infiltrations rachidiennes', 'relations': []}],
#  [1705,
#   1733,
#   {'id': 'c21',
#    'term': 'Prise en charge chirurgicale',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'Pistes; Prises'}]}],
#  [1869, 1888, {'id': 'c22', 'term': 'non médicamenteuses', 'relations': []}],
#  [1987,
#   1994,
#   {'id': 'c23',
#    'term': 'Aspects',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c24',
#      'related terms': 'récidive de lombalgie'}]}],
#  [2041,
#   2062,
#   {'id': 'c24',
#    'term': 'récidive de lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c12',
#      'related terms': 'douleur lombaire'}]}],
#  [0, 15, {'id': 'c1', 'term': 'Version soumise', 'relations': []}],
#  [20,
#   37,
#   {'id': 'c2',
#    'term': 'parties prenantes',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'Version soumise'}]}],
#  [0, 4, {'id': 'c1', 'term': 'Avis', 'relations': []}],
#  [9, 26, {'id': 'c2', 'term': 'parties prenantes', 'relations': []}],
#  [0, 10, {'id': 'c1', 'term': 'Validation', 'relations': []}],
#  [144, 152, {'id': 'c2', 'term': 'Adoption', 'relations': []}],
#  [160,
#   177,
#   {'id': 'c3',
#    'term': 'Collège de la HAS',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c2',
#      'related terms': 'Adoption'}]}],
#  [0, 22, {'id': 'c01', 'term': 'Recherche documentaire', 'relations': []}],
#  [138, 148, {'id': 'c02', 'term': 'Références', 'relations': []}],
#  [433, 446, {'id': 'c02', 'term': 'Remerciements', 'relations': []}],
#  [285, 297, {'id': 'c03', 'term': 'Participants', 'relations': []}],
#  [725,
#   728,
#   {'id': 'c04',
#    'term': 'HAS',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'acronymes'},
#     {'type': 'associativeRelation',
#      'related concept': 'c05',
#      'related terms': 'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'},
#     {'type': 'associativeRelation',
#      'related concept': 'c11',
#      'related terms': 'non stéroïdiens'}]}],
#  [893,
#   912,
#   {'id': 'c04',
#    'term': 'Anti-inflammatoires',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'acronymes'},
#     {'type': 'associativeRelation',
#      'related concept': 'c05',
#      'related terms': 'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'},
#     {'type': 'associativeRelation',
#      'related concept': 'c11',
#      'related terms': 'non stéroïdiens'}]}],
#  [939,
#   978,
#   {'id': 'c04',
#    'term': 'Caisse nationale de l’Assurance maladie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'acronymes'},
#     {'type': 'associativeRelation',
#      'related concept': 'c05',
#      'related terms': 'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'},
#     {'type': 'associativeRelation',
#      'related concept': 'c11',
#      'related terms': 'non stéroïdiens'}]}],
#  [731,
#   776,
#   {'id': 'c05',
#    'term': 'Service des bonnes pratiques professionnelles',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'}]}],
#  [882,
#   886,
#   {'id': 'c05',
#    'term': 'AINS',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'}]}],
#  [930,
#   934,
#   {'id': 'c05',
#    'term': 'CNAM',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'}]}],
#  [576,
#   593,
#   {'id': 'c05',
#    'term': 'Fiche descriptive',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'}]}],
#  [980,
#   984,
#   {'id': 'c05',
#    'term': 'DGOS',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'}]}],
#  [794,
#   799,
#   {'id': 'c06',
#    'term': 'Prise',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'},
#     {'type': 'activityRelation',
#      'related concept': 'c08',
#      'related terms': 'lombalgie commune'}]}],
#  [813,
#   820,
#   {'id': 'c07',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c08',
#      'related terms': 'lombalgie commune'}]}],
#  [836, 853, {'id': 'c08', 'term': 'lombalgie commune', 'relations': []}],
#  [855,
#   867,
#   {'id': 'c09',
#    'term': 'Abréviations',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c02',
#      'related terms': 'Références; Remerciements'},
#     {'type': 'associativeRelation',
#      'related concept': 'c10',
#      'related terms': 'acronymes'}]}],
#  [871, 880, {'id': 'c10', 'term': 'acronymes', 'relations': []}],
#  [913, 928, {'id': 'c11', 'term': 'non stéroïdiens', 'relations': []}],
#  [0,
#   18,
#   {'id': 'c1',
#    'term': 'Direction générale',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'soins'}]}],
#  [33, 38, {'id': 'c2', 'term': 'soins', 'relations': []}],
#  [52,
#   79,
#   {'id': 'c3', 'term': 'Échelle visuelle analogique', 'relations': []}],
#  [81, 85, {'id': 'c4', 'term': 'FABQ', 'relations': []}],
#  [104, 127, {'id': 'c01', 'term': 'Intervalle de confiance', 'relations': []}],
#  [413, 422, {'id': 'c02', 'term': 'Optimized', 'relations': []}],
#  [423,
#   431,
#   {'id': 'c03',
#    'term': 'Practice',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [49,
#   80,
#   {'id': 'c03',
#    'term': 'Hospital Anxiety and Depression',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [0,
#   35,
#   {'id': 'c03',
#    'term': 'Fear Avoidance Belief Questionnaire',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [129,
#   132,
#   {'id': 'c03',
#    'term': 'IRM',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [177,
#   180,
#   {'id': 'c03',
#    'term': 'KCE',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [338,
#   342,
#   {'id': 'c03',
#    'term': 'TENS',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [439,
#   442,
#   {'id': 'c03',
#    'term': 'HAS',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [142,
#   175,
#   {'id': 'c03',
#    'term': 'Imagerie par résonance magnétique',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [189,
#   225,
#   {'id': 'c03',
#    'term': 'Belgian Health Care Knowledge Centre',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [287,
#   336,
#   {'id': 'c03',
#    'term': 'National Institute for Health and Care Excellence',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [348,
#   391,
#   {'id': 'c03',
#    'term': 'Transcutaneous Electrical Nerve Stimulation',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [445,
#   490,
#   {'id': 'c03',
#    'term': 'Service des bonnes pratiques professionnelles',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [592,
#   631,
#   {'id': 'c03',
#    'term': 'Caisse nationale de l’Assurance maladie',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [645,
#   677,
#   {'id': 'c03',
#    'term': 'Direction générale de l’offre de',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [710,
#   736,
#   {'id': 'c03',
#    'term': 'Haute Autorité de Santé',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [900,
#   923,
#   {'id': 'c03',
#    'term': 'professionnels de santé',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [580,
#   587,
#   {'id': 'c03',
#    'term': 'Saisine',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c02',
#      'related terms': 'Optimized'},
#     {'type': 'genericRelation',
#      'related concept': 'c08',
#      'related terms': 'recommandations de bonne pratique'},
#     {'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [508,
#   513,
#   {'id': 'c04',
#    'term': 'Prise',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [527,
#   534,
#   {'id': 'c05',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c04',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c06',
#      'related terms': 'lombalgie commune'}]}],
#  [550, 567, {'id': 'c06', 'term': 'lombalgie commune', 'relations': []}],
#  [679, 684, {'id': 'c07', 'term': 'soins', 'relations': []}],
#  [769,
#   802,
#   {'id': 'c08',
#    'term': 'recommandations de bonne pratique',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c10',
#      'related terms': 'patient présentant'}]}],
#  [820, 835, {'id': 'c09', 'term': 'prise en charge', 'relations': []}],
#  [839,
#   857,
#   {'id': 'c10',
#    'term': 'patient présentant',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c09',
#      'related terms': 'prise en charge'}]}],
#  [950, 972, {'id': 'c11', 'term': 'médecins généralistes', 'relations': []}],
#  [4, 11, {'id': 'c1', 'term': 'travail', 'relations': []}],
#  [42, 50, {'id': 'c2', 'term': 'campagne', 'relations': []}],
#  [56, 71, {'id': 'c3', 'term': 'sensibilisation', 'relations': []}],
#  [77,
#   90,
#   {'id': 'c4',
#    'term': 'grand public',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'travail'},
#     {'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'sensibilisation'}]}],
#  [111,
#   126,
#   {'id': 'c5',
#    'term': 'prise en charge',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'lombalgie commune'}]}],
#  [133, 151, {'id': 'c6', 'term': 'lombalgie commune', 'relations': []}],
#  [19,
#   31,
#   {'id': 'c01',
#    'term': 'publications',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c02',
#      'related terms': 'recommandations'}]}],
#  [47, 62, {'id': 'c02', 'term': 'recommandations', 'relations': []}],
#  [85, 100, {'id': 'c03', 'term': 'internationales', 'relations': []}],
#  [122,
#   167,
#   {'id': 'c04',
#    'term': 'Centre fédéral d’expertise des soins de santé',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c03',
#      'related terms': 'internationales'}]}],
#  [181,
#   230,
#   {'id': 'c05',
#    'term': 'National Institute for Health and Care Excellence',
#    'relations': []}],
#  [302,
#   318,
#   {'id': 'c06',
#    'term': 'soins français',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'prescriptions'}]}],
#  [347, 360, {'id': 'c07', 'term': 'prescriptions', 'relations': []}],
#  [395,
#   424,
#   {'id': 'c08', 'term': 'prescriptions thérapeutiques', 'relations': []}],
#  [453,
#   461,
#   {'id': 'c09',
#    'term': 'parcours',
#    'relations': [{'type': 'instrumentalRelation',
#      'related concept': 'c10',
#      'related terms': 'prise en charge'},
#     {'type': 'activityRelation',
#      'related concept': 'c11',
#      'related terms': 'lombalgie commune'}]}],
#  [476,
#   491,
#   {'id': 'c10',
#    'term': 'prise en charge',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c11',
#      'related terms': 'lombalgie commune'}]}],
#  [498, 516, {'id': 'c11', 'term': 'lombalgie commune', 'relations': []}],
#  [0, 8, {'id': 'c1', 'term': 'Contexte', 'relations': []}],
#  [27,
#   36,
#   {'id': 'c2',
#    'term': 'lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c5',
#      'related terms': 'problème'},
#     {'type': 'associativeRelation',
#      'related concept': 'c6',
#      'related terms': 'santé publique'},
#     {'type': 'associativeRelation',
#      'related concept': 'c7',
#      'related terms': 'santé'}]}],
#  [37,
#   42,
#   {'id': 'c3',
#    'term': 'aiguë',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'chronique'}]}],
#  [46,
#   55,
#   {'id': 'c4',
#    'term': 'chronique',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c5',
#      'related terms': 'problème'},
#     {'type': 'associativeRelation',
#      'related concept': 'c7',
#      'related terms': 'santé'}]}],
#  [75,
#   83,
#   {'id': 'c5',
#    'term': 'problème',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c6',
#      'related terms': 'santé publique'}]}],
#  [87,
#   101,
#   {'id': 'c6',
#    'term': 'santé publique',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c7',
#      'related terms': 'santé'}]}],
#  [108, 113, {'id': 'c7', 'term': 'santé', 'relations': []}],
#  [156,
#   184,
#   {'id': 'c8', 'term': 'désinsertion professionnelle', 'relations': []}],
#  [213, 227, {'id': 'c9', 'term': 'social majeur', 'relations': []}],
#  [0, 13, {'id': 'c1', 'term': 'Épidémiologie', 'relations': []}],
#  [18, 28, {'id': 'c2', 'term': 'prévalence', 'relations': []}],
#  [35, 44, {'id': 'c3', 'term': 'lombalgie', 'relations': []}],
#  [32,
#   40,
#   {'id': 'c1',
#    'term': 'patients',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c2',
#      'related terms': 'guérissent'},
#     {'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgie subaiguë'}]}],
#  [41,
#   51,
#   {'id': 'c2',
#    'term': 'guérissent',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgie subaiguë'}]}],
#  [87, 105, {'id': 'c3', 'term': 'lombalgie subaiguë', 'relations': []}],
#  [19,
#   55,
#   {'id': 'c1',
#    'term': 'observatoire de la médecine générale',
#    'relations': []}],
#  [92,
#   99,
#   {'id': 'c2',
#    'term': 'données',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c3',
#      'related terms': 'patients'}]}],
#  [128, 136, {'id': 'c3', 'term': 'patients', 'relations': []}],
#  [204, 213, {'id': 'c4', 'term': 'résultats', 'relations': []}],
#  [219,
#   232,
#   {'id': 'c5',
#    'term': 'consultations',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c4',
#      'related terms': 'résultats'},
#     {'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'prescriptions'}]}],
#  [255, 265, {'id': 'c6', 'term': 'lignes de', 'relations': []}],
#  [267,
#   280,
#   {'id': 'c7',
#    'term': 'prescriptions',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c6',
#      'related terms': 'lignes de'}]}],
#  [282,
#   298,
#   {'id': 'c8',
#    'term': 'médicamenteuses',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c9',
#      'related terms': 'saisis en temps réel'}]}],
#  [300, 324, {'id': 'c9', 'term': 'saisis en temps réel', 'relations': []}],
#  [34, 41, {'id': 'c1', 'term': 'médecin', 'relations': []}],
#  [43,
#   63,
#   {'id': 'c2',
#    'term': 'généraliste français',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'patients'},
#     {'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'lombalgie'}]}],
#  [72,
#   80,
#   {'id': 'c3',
#    'term': 'patients',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'lombalgie'}]}],
#  [90, 100, {'id': 'c4', 'term': 'lombalgie', 'relations': []}],
#  [154, 162, {'id': 'c5', 'term': 'problème', 'relations': []}],
#  [3,
#   14,
#   {'id': 'c1',
#    'term': 'répartition',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c2',
#      'related terms': 'patients lombalgiques'}]}],
#  [19,
#   40,
#   {'id': 'c2',
#    'term': 'patients lombalgiques',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c3',
#      'related terms': 'tranche'}]}],
#  [45, 52, {'id': 'c3', 'term': 'tranche', 'relations': []}],
#  [121,
#   127,
#   {'id': 'c4',
#    'term': 'hommes',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c5',
#      'related terms': 'femmes'}]}],
#  [138, 145, {'id': 'c5', 'term': 'femmes', 'relations': []}],
#  [4,
#   13,
#   {'id': 'c1',
#    'term': 'lombalgie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'patients'}]}],
#  [40, 48, {'id': 'c2', 'term': 'patients', 'relations': []}],
#  [18, 28, {'id': 'c1', 'term': 'prévalence', 'relations': []}],
#  [35,
#   44,
#   {'id': 'c2',
#    'term': 'lombalgie',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c1',
#      'related terms': 'prévalence'}]}],
#  [10,
#   25,
#   {'id': 'c1',
#    'term': 'Handicap-Santé',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'population'}]}],
#  [74, 84, {'id': 'c2', 'term': 'population', 'relations': []}],
#  [98, 105, {'id': 'c3', 'term': 'France', 'relations': []}],
#  [165,
#   177,
#   {'id': 'c4',
#    'term': 'lieu de vie',
#    'relations': [{'type': 'spatialRelation',
#      'related concept': 'c3',
#      'related terms': 'France'}]}],
#  [4, 15, {'id': 'c1', 'term': 'appariement', 'relations': []}],
#  [25,
#   32,
#   {'id': 'c2',
#    'term': 'données',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'appariement'}]}],
#  [95,
#   134,
#   {'id': 'c3',
#    'term': "régimes de l'Assurance maladie-Sniiram",
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'recours'}]}],
#  [176, 183, {'id': 'c4', 'term': 'recours', 'relations': []}],
#  [190, 195, {'id': 'c5', 'term': 'soins', 'relations': []}],
#  [206, 225, {'id': 'c6', 'term': 'dépenses de santé', 'relations': []}],
#  [232,
#   241,
#   {'id': 'c7',
#    'term': 'personnes',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c5',
#      'related terms': 'soins'},
#     {'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'dépenses de santé'}]}],
#  [24,
#   33,
#   {'id': 'c1',
#    'term': 'extraites',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c2',
#      'related terms': 'enquête'},
#     {'type': 'originationRelation',
#      'related concept': 'c4',
#      'related terms': 'population française'}]}],
#  [43, 50, {'id': 'c2', 'term': 'enquête', 'relations': []}],
#  [59,
#   65,
#   {'id': 'c3',
#    'term': 'sujets',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c2',
#      'related terms': 'enquête'},
#     {'type': 'partitiveRelation',
#      'related concept': 'c4',
#      'related terms': 'population française'}]}],
#  [87, 108, {'id': 'c4', 'term': 'population française', 'relations': []}],
#  [140, 150, {'id': 'c5', 'term': 'population', 'relations': []}],
#  [239,
#   286,
#   {'id': 'c6',
#    'term': 'maladie musculosquelettique et rhumatismale',
#    'relations': []}],
#  [323, 332, {'id': 'c7', 'term': 'lombalgie', 'relations': []}],
#  [0,
#   3,
#   {'id': 'c01',
#    'term': 'HAS',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c02',
#      'related terms': 'Service des bonnes pratiques professionnelles'}]}],
#  [6,
#   51,
#   {'id': 'c02',
#    'term': 'Service des bonnes pratiques professionnelles',
#    'relations': []}],
#  [69,
#   74,
#   {'id': 'c03',
#    'term': 'Prise',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c05',
#      'related terms': 'lombalgie commune'}]}],
#  [88,
#   95,
#   {'id': 'c04',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c03',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c05',
#      'related terms': 'lombalgie commune'}]}],
#  [111, 128, {'id': 'c05', 'term': 'lombalgie commune', 'relations': []}],
#  [135,
#   142,
#   {'id': 'c06',
#    'term': 'données',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c07',
#      'related terms': 'réseau'},
#     {'type': 'originationRelation',
#      'related concept': 'c08',
#      'related terms': 'OSCOUR®'}]}],
#  [148, 154, {'id': 'c07', 'term': 'réseau', 'relations': []}],
#  [156,
#   163,
#   {'id': 'c08',
#    'term': 'OSCOUR®',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c07',
#      'related terms': 'réseau'}]}],
#  [254, 261, {'id': 'c09', 'term': 'recours', 'relations': []}],
#  [266,
#   288,
#   {'id': 'c10',
#    'term': 'structures d’urgences',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c09',
#      'related terms': 'recours'}]}],
#  [339, 352, {'id': 'c11', 'term': 'publication)', 'relations': []}],
#  [48,
#   56,
#   {'id': 'c1',
#    'term': 'passages',
#    'relations': [{'type': 'spatialRelation',
#      'related concept': 'c2',
#      'related terms': 'urgences'}]}],
#  [61,
#   69,
#   {'id': 'c2',
#    'term': 'urgences',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgie commune'}]}],
#  [75, 92, {'id': 'c3', 'term': 'lombalgie commune', 'relations': []}],
#  [29,
#   38,
#   {'id': 'c1',
#    'term': 'lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c3',
#      'related terms': 'diagnostic principal'}]}],
#  [48,
#   53,
#   {'id': 'c2',
#    'term': 'codée',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c1',
#      'related terms': 'lombalgie'}]}],
#  [62, 84, {'id': 'c3', 'term': 'diagnostic principal', 'relations': []}],
#  [5,
#   13,
#   {'id': 'c1',
#    'term': 'passages',
#    'relations': [{'type': 'spatialRelation',
#      'related concept': 'c4',
#      'related terms': 'période'}]}],
#  [57,
#   70,
#   {'id': 'c2',
#    'term': 'causes codées',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'code diagnostic'}]}],
#  [98, 114, {'id': 'c3', 'term': 'code diagnostic', 'relations': []}],
#  [181, 189, {'id': 'c4', 'term': 'période', 'relations': []}],
#  [5, 13, {'id': 'c1', 'term': 'passages', 'relations': []}],
#  [21, 38, {'id': 'c2', 'term': 'lombalgie commune', 'relations': []}],
#  [132, 136, {'id': 'c3', 'term': 'ans', 'relations': []}],
#  [21,
#   29,
#   {'id': 'c1',
#    'term': 'passages',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'lombalgie'}]}],
#  [35,
#   44,
#   {'id': 'c2',
#    'term': 'lombalgie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'hospitalisation'},
#     {'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'taux'}]}],
#  [68,
#   84,
#   {'id': 'c3',
#    'term': 'hospitalisation',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'taux'}]}],
#  [91, 95, {'id': 'c4', 'term': 'taux', 'relations': []}],
#  [138, 146, {'id': 'c5', 'term': 'patient', 'relations': []}],
#  [0,
#   4,
#   {'id': 'c1',
#    'term': 'État',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c2',
#      'related terms': 'pratiques'},
#     {'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'prise en charge'}]}],
#  [23,
#   32,
#   {'id': 'c2',
#    'term': 'pratiques',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'prise en charge'}]}],
#  [57, 72, {'id': 'c3', 'term': 'prise en charge', 'relations': []}],
#  [121, 136, {'id': 'c4', 'term': 'recommandations', 'relations': []}],
#  [18, 25, {'id': 'c01', 'term': 'données', 'relations': []}],
#  [96,
#   115,
#   {'id': 'c02',
#    'term': 'radiographie du dos',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c03',
#      'related terms': 'lombalgie'}]}],
#  [121,
#   130,
#   {'id': 'c03',
#    'term': 'lombalgie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'patients'}]}],
#  [154,
#   164,
#   {'id': 'c04',
#    'term': 'recommandé',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c05',
#      'related terms': 'drapeaux rouges'}]}],
#  [202, 217, {'id': 'c05', 'term': 'drapeaux rouges', 'relations': []}],
#  [269,
#   282,
#   {'id': 'c06',
#    'term': 'arrêt maladie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c03',
#      'related terms': 'lombalgie'}]}],
#  [309,
#   317,
#   {'id': 'c07',
#    'term': 'patients',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c08',
#      'related terms': 'kinésithérapie'}]}],
#  [338, 352, {'id': 'c08', 'term': 'kinésithérapie', 'relations': []}],
#  [472, 480, {'id': 'c09', 'term': 'consulté', 'relations': []}],
#  [484,
#   497,
#   {'id': 'c10',
#    'term': 'rhumatologue',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c09',
#      'related terms': 'consulté'}]}],
#  [0, 12, {'id': 'c01', 'term': 'Alternatives', 'relations': []}],
#  [13,
#   31,
#   {'id': 'c02',
#    'term': 'interventionnelles',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c01',
#      'related terms': 'Alternatives'}]}],
#  [63,
#   79,
#   {'id': 'c03',
#    'term': 'prises en charge',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c04',
#      'related terms': 'non médicamenteuses'}]}],
#  [80, 99, {'id': 'c04', 'term': 'non médicamenteuses', 'relations': []}],
#  [125,
#   139,
#   {'id': 'c05',
#    'term': 'techniques ma',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c03',
#      'related terms': 'prises en charge'}]}],
#  [140,
#   148,
#   {'id': 'c06',
#    'term': 'nuelles',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'interventions psychologiques'}]}],
#  [150,
#   180,
#   {'id': 'c07', 'term': 'interventions psychologiques', 'relations': []}],
#  [182,
#   192,
#   {'id': 'c08',
#    'term': 'ceintures',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c06',
#      'related terms': 'nuelles'},
#     {'type': 'genericRelation',
#      'related concept': 'c07',
#      'related terms': 'interventions psychologiques'}]}],
#  [194,
#   218,
#   {'id': 'c09',
#    'term': 'semelles orthopédiques',
#    'relations': [{'type': 'partitiveRelation',
# ...
#      'related terms': 'radiculalgie'}]}],
#  [68, 80, {'id': 'c4', 'term': 'radiculalgie', 'relations': []}],
#  [109,
#   119,
#   {'id': 'c5',
#    'term': 'États-Unis',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c2',
#      'related terms': 'recommandations'}]}],
#  [131,
#   137,
#   {'id': 'c6',
#    'term': 'Canada',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c8',
#      'related terms': 'sciatique'}]}],
#  [152,
#   168,
#   {'id': 'c7',
#    'term': 'NICE britannique',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c6',
#      'related terms': 'Canada'},
#     {'type': 'associativeRelation',
#      'related concept': 'c8',
#      'related terms': 'sciatique'}]}],
#  [192, 201, {'id': 'c8', 'term': 'sciatique', 'relations': []}],
#  [0, 4, {'id': 'c1', 'term': 'Seul', 'relations': []}],
#  [9,
#   18,
#   {'id': 'c2',
#    'term': 'KCE belge',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'définition'},
#     {'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'radiculalgie'},
#     {'type': 'activityRelation',
#      'related concept': 'c5',
#      'related terms': 'consensus'}]}],
#  [31,
#   41,
#   {'id': 'c3',
#    'term': 'définition',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c4',
#      'related terms': 'radiculalgie'}]}],
#  [48,
#   61,
#   {'id': 'c4',
#    'term': 'radiculalgie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c5',
#      'related terms': 'consensus'}]}],
#  [89, 98, {'id': 'c5', 'term': 'consensus', 'relations': []}],
#  [7, 25, {'id': 'c1', 'term': 'revue systématique', 'relations': []}],
#  [32, 43, {'id': 'c2', 'term': 'littérature', 'relations': []}],
#  [70, 80, {'id': 'c3', 'term': 'recherche', 'relations': []}],
#  [5,
#   12,
#   {'id': 'c01',
#    'term': 'données',
#    'relations': [{'type': 'originationRelation',
#      'related concept': 'c02',
#      'related terms': 'méta-analyse'},
#     {'type': 'associativeRelation',
#      'related concept': 'c04',
#      'related terms': 'lombalgie'}]}],
#  [21,
#   33,
#   {'id': 'c02',
#    'term': 'méta-analyse',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c04',
#      'related terms': 'lombalgie'}]}],
#  [61, 73, {'id': 'c03', 'term': 'terminologie', 'relations': []}],
#  [81,
#   90,
#   {'id': 'c04',
#    'term': 'lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c10',
#      'related terms': 'douleur; douleurs'}]}],
#  [148, 158, {'id': 'c05', 'term': 'définition', 'relations': []}],
#  [189,
#   201,
#   {'id': 'c06',
#    'term': 'récidivante',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c07',
#      'related terms': 'études'},
#     {'type': 'associativeRelation',
#      'related concept': 'c08',
#      'related terms': 'récurrences'}]}],
#  [232, 238, {'id': 'c07', 'term': 'études', 'relations': []}],
#  [256,
#   268,
#   {'id': 'c08',
#    'term': 'récurrences',
#    'relations': [{'type': 'partitiveRelation',
#      'related concept': 'c07',
#      'related terms': 'études'}]}],
#  [299, 307, {'id': 'c09', 'term': 'sévérité', 'relations': []}],
#  [314,
#   322,
#   {'id': 'c10',
#    'term': 'douleur',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c09',
#      'related terms': 'sévérité'}]}],
#  [342,
#   351,
#   {'id': 'c10',
#    'term': 'douleurs',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c09',
#      'related terms': 'sévérité'}]}],
#  [13, 24, {'id': 'c1', 'term': 'récurrences', 'relations': []}],
#  [40, 49, {'id': 'c2', 'term': 'lombalgie', 'relations': []}],
#  [141, 153, {'id': 'c3', 'term': 'méta-analyse', 'relations': []}],
#  [168, 174, {'id': 'c4', 'term': 'études', 'relations': []}],
#  [199, 205, {'id': 'c5', 'term': 'répété', 'relations': []}],
#  [214, 223, {'id': 'c6', 'term': 'récurrent', 'relations': []}],
#  [4,
#   9,
#   {'id': 'c1',
#    'term': 'revue',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'méta-analyse'}]}],
#  [16,
#   27,
#   {'id': 'c2',
#    'term': 'littérature',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'méta-analyse'}]}],
#  [34,
#   47,
#   {'id': 'c3',
#    'term': 'méta-analyse',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'trajectoires de douleur'}]}],
#  [65, 88, {'id': 'c4', 'term': 'trajectoires de douleur', 'relations': []}],
#  [94,
#   116,
#   {'id': 'c5',
#    'term': 'patients lombalgiques',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c6',
#      'related terms': 'douleurs fluctuantes'}]}],
#  [136, 156, {'id': 'c6', 'term': 'douleurs fluctuantes', 'relations': []}],
#  [196,
#   204,
#   {'id': 'c7',
#    'term': 'patients',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c8',
#      'related terms': 'lombalgiques'}]}],
#  [205, 217, {'id': 'c8', 'term': 'lombalgiques', 'relations': []}],
#  [4,
#   19,
#   {'id': 'c1',
#    'term': 'recommandations',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgies chroniques'}]}],
#  [20,
#   30,
#   {'id': 'c2',
#    'term': 'allemandes',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c1',
#      'related terms': 'recommandations'},
#     {'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgies chroniques'}]}],
#  [52, 73, {'id': 'c3', 'term': 'lombalgies chroniques', 'relations': []}],
#  [118,
#   128,
#   {'id': 'c4',
#    'term': 'lombalgies',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c5',
#      'related terms': 'risque'},
#     {'type': 'associativeRelation',
#      'related concept': 'c6',
#      'related terms': 'chronicisation'}]}],
#  [131,
#   137,
#   {'id': 'c5',
#    'term': 'risque',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c6',
#      'related terms': 'chronicisation'}]}],
#  [141, 155, {'id': 'c6', 'term': 'chronicisation', 'relations': []}],
#  [193,
#   223,
#   {'id': 'c7', 'term': 'évaluation multidisciplinaire', 'relations': []}],
#  [11,
#   26,
#   {'id': 'c1',
#    'term': 'recommandations',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'terme'}]}],
#  [46, 51, {'id': 'c2', 'term': 'terme', 'relations': []}],
#  [58, 67, {'id': 'c3', 'term': 'lombalgie', 'relations': []}],
#  [0, 15, {'id': 'c1', 'term': 'Recommandations', 'relations': []}],
#  [23, 32, {'id': 'c2', 'term': 'lombalgie', 'relations': []}],
#  [53, 60, {'id': 'c3', 'term': 'douleur', 'relations': []}],
#  [77,
#   103,
#   {'id': 'c4', 'term': 'charnière thoraco-lombaire', 'relations': []}],
#  [111, 133, {'id': 'c5', 'term': 'pli fessier inférieur', 'relations': []}],
#  [39,
#   51,
#   {'id': 'c1',
#    'term': 'radiculalgie',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'douleur'}]}],
#  [72, 79, {'id': 'c2', 'term': 'douleur', 'relations': []}],
#  [98,
#   116,
#   {'id': 'c3',
#    'term': 'membres inférieurs',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c4',
#      'related terms': 'dermatomes'}]}],
#  [145, 156, {'id': 'c4', 'term': 'dermatomes', 'relations': []}],
#  [13,
#   30,
#   {'id': 'c1',
#    'term': 'lombalgie commune',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'signes'}]}],
#  [43,
#   59,
#   {'id': 'c2',
#    'term': 'douleur lombaire',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c3',
#      'related terms': 'signes'}]}],
#  [83, 89, {'id': 'c3', 'term': 'signes', 'relations': []}],
#  [91, 99, {'id': 'c4', 'term': 'd’alerte', 'relations': []}],
#  [0, 5, {'id': 'c1', 'term': 'liste', 'relations': []}],
#  [6,
#   23,
#   {'id': 'c2',
#    'term': 'drapeaux rouges)',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c1',
#      'related terms': 'liste'}]}],
#  [14, 31, {'id': 'c1', 'term': 'lombalgie commune', 'relations': []}],
#  [59, 83, {'id': 'c1', 'term': 'lombalgie non spécifique', 'relations': []}],
#  [90, 108, {'id': 'c2', 'term': 'pratique courante', 'relations': []}],
#  [6,
#   9,
#   {'id': 'c1',
#    'term': 'HAS',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'Service des bonnes pratiques professionnelles'}]}],
#  [12,
#   57,
#   {'id': 'c2',
#    'term': 'Service des bonnes pratiques professionnelles',
#    'relations': []}],
#  [74,
#   79,
#   {'id': 'c3',
#    'term': 'Prise',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c5',
#      'related terms': 'lombalgie commune'}]}],
#  [93,
#   100,
#   {'id': 'c4',
#    'term': 'patient',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c3',
#      'related terms': 'Prise'},
#     {'type': 'associativeRelation',
#      'related concept': 'c5',
#      'related terms': 'lombalgie commune'},
#     {'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'termes'},
#     {'type': 'activityRelation',
#      'related concept': 'c7',
#      'related terms': 'diagnostic'}]}],
#  [116,
#   133,
#   {'id': 'c5',
#    'term': 'lombalgie commune',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c8',
#      'related terms': 'rassurante'},
#     {'type': 'propertyRelation',
#      'related concept': 'c9',
#      'related terms': 'pronostic'}]}],
#  [183, 189, {'id': 'c6', 'term': 'termes', 'relations': []}],
#  [193, 204, {'id': 'c7', 'term': 'diagnostic', 'relations': []}],
#  [238, 248, {'id': 'c8', 'term': 'rassurante', 'relations': []}],
#  [261,
#   270,
#   {'id': 'c9',
#    'term': 'pronostic',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c8',
#      'related terms': 'rassurante'}]}],
#  [13,
#   32,
#   {'id': 'c1',
#    'term': 'lombalgie chronique',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'lombalgie'}]}],
#  [53, 62, {'id': 'c2', 'term': 'lombalgie', 'relations': []}],
#  [0,
#   6,
#   {'id': 'c01',
#    'term': 'Pistes',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c02',
#      'related terms': 'définition'},
#     {'type': 'associativeRelation',
#      'related concept': 'c03',
#      'related terms': 'lombalgie commune'}]}],
#  [46,
#   56,
#   {'id': 'c02',
#    'term': 'définition',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c03',
#      'related terms': 'lombalgie commune'}]}],
#  [63,
#   80,
#   {'id': 'c03',
#    'term': 'lombalgie commune',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c18',
#      'related terms': 'lombalgie récidivante; lombalgie'}]}],
#  [113, 119, {'id': 'c04', 'term': 'termes', 'relations': []}],
#  [131,
#   160,
#   {'id': 'c05',
#    'term': 'poussée aiguë de lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c12',
#      'related terms': 'lombalgie à risque de chronicité'}]}],
#  [179,
#   195,
#   {'id': 'c05',
#    'term': 'lombalgie aiguë',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c12',
#      'related terms': 'lombalgie à risque de chronicité'}]}],
#  [223,
#   240,
#   {'id': 'c06',
#    'term': 'douleurs aiguës',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c09',
#      'related terms': 'traitements'}]}],
#  [258,
#   275,
#   {'id': 'c07',
#    'term': 'douleur de fond',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c06',
#      'related terms': 'douleurs aiguës'}]}],
#  [310,
#   336,
#   {'id': 'c08',
#    'term': 'intensification temporaire',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c09',
#      'related terms': 'traitements'},
#     {'type': 'activityRelation',
#      'related concept': 'c10',
#      'related terms': 'médicamenteux ou non médicamenteux'},
#     {'type': 'genericRelation',
#      'related concept': 'c04',
#      'related terms': 'termes'}]}],
#  [419,
#   429,
#   {'id': 'c08',
#    'term': 'temporaire',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c09',
#      'related terms': 'traitements'},
#     {'type': 'activityRelation',
#      'related concept': 'c10',
#      'related terms': 'médicamenteux ou non médicamenteux'},
#     {'type': 'genericRelation',
#      'related concept': 'c04',
#      'related terms': 'termes'}]}],
#  [341, 352, {'id': 'c09', 'term': 'traitements', 'relations': []}],
#  [353,
#   388,
#   {'id': 'c10',
#    'term': 'médicamenteux ou non médicamenteux',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c09',
#      'related terms': 'traitements'}]}],
#  [434,
#   458,
#   {'id': 'c11', 'term': 'capacités fonctionnelles', 'relations': []}],
#  [467,
#   499,
#   {'id': 'c12',
#    'term': 'lombalgie à risque de chronicité',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c18',
#      'related terms': 'lombalgie récidivante; lombalgie'},
#     {'type': 'associativeRelation',
#      'related concept': 'c13',
#      'related terms': 'patients'},
#     {'type': 'associativeRelation',
#      'related concept': 'c14',
#      'related terms': 'durée d’évolution'}]}],
#  [511,
#   519,
#   {'id': 'c13',
#    'term': 'patients',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c14',
#      'related terms': 'durée d’évolution'}]}],
#  [530, 547, {'id': 'c14', 'term': 'durée d’évolution', 'relations': []}],
#  [603, 609, {'id': 'c15', 'term': 'risque', 'relations': []}],
#  [629,
#   639,
#   {'id': 'c16',
#    'term': 'résolution',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c11',
#      'related terms': 'capacités fonctionnelles'}]}],
#  [673, 689, {'id': 'c17', 'term': 'drapeaux jaunes', 'relations': []}],
#  [698,
#   719,
#   {'id': 'c18',
#    'term': 'lombalgie récidivante',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c07',
#      'related terms': 'douleur de fond'},
#     {'type': 'associativeRelation',
#      'related concept': 'c15',
#      'related terms': 'risque'},
#     {'type': 'associativeRelation',
#      'related concept': 'c17',
#      'related terms': 'drapeaux jaunes'}]}],
#  [555,
#   564,
#   {'id': 'c18',
#    'term': 'lombalgie',
#    'relations': [{'type': 'genericRelation',
#      'related concept': 'c07',
#      'related terms': 'douleur de fond'},
#     {'type': 'associativeRelation',
#      'related concept': 'c15',
#      'related terms': 'risque'},
#     {'type': 'associativeRelation',
#      'related concept': 'c17',
#      'related terms': 'drapeaux jaunes'}]}],
#  [732,
#   740,
#   {'id': 'c19',
#    'term': 'récidive',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c18',
#      'related terms': 'lombalgie récidivante; lombalgie'}]}],
#  [37,
#   46,
#   {'id': 'c1',
#    'term': 'lombalgie',
#    'relations': [{'type': 'propertyRelation',
#      'related concept': 'c2',
#      'related terms': 'risque'}]}],
#  [49, 55, {'id': 'c2', 'term': 'risque', 'relations': []}],
#  [4,
#   9,
#   {'id': 'c1',
#    'term': 'Prise',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c2',
#      'related terms': 'patient'},
#     {'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgique'}]}],
#  [31,
#   38,
#   {'id': 'c2',
#    'term': 'patient',
#    'relations': [{'type': 'associativeRelation',
#      'related concept': 'c3',
#      'related terms': 'lombalgique'},
#     {'type': 'activityRelation',
#      'related concept': 'c5',
#      'related terms': 'prise en charge'},
#     {'type': 'activityRelation',
#      'related concept': 'c6',
#      'related terms': 'vécu'},
#     {'type': 'associativeRelation',
#      'related concept': 'c8',
#      'related terms': 'douleur'}]}],
#  [39, 50, {'id': 'c3', 'term': 'lombalgique', 'relations': []}],
#  [52, 67, {'id': 'c4', 'term': 'Recommandations', 'relations': []}],
#  [75, 90, {'id': 'c5', 'term': 'prise en charge', 'relations': []}],
#  [150, 154, {'id': 'c6', 'term': 'vécu', 'relations': []}],
#  [173,
#   187,
#   {'id': 'c7',
#    'term': 'retentissement',
#    'relations': [{'type': 'activityRelation',
#      'related concept': 'c8',
#      'related terms': 'douleur'}]}],
#  ...]

# %%
len(dictRest)
# Out:
# 1765

# %% [markdown]
# ## Extracting relations

# %%
def makeTriple(term, relations):
    triples = []
    for relation in relations:
        triples.append((term, relation['type'], relation['related terms']))
    return triples

# %%
relations = []
for entity in dictRest:
    if entity[2]['relations']:
        relations += makeTriple(entity[2]['term'], entity[2]['relations'])

# %%
relations[:]
# Out:
# [('FICHE MÉMO', 'genericRelation', 'document'),
#  ('fiches mémo', 'genericRelation', 'document'),
#  ('Prise en charge', 'genericRelation', 'Prise'),
#  ('Prise en charge', 'associativeRelation', 'patient présentant'),
#  ('lombalgie commune', 'genericRelation', 'méthode d’élaboration'),
#  ('RAPPORT D’ÉLABORATION', 'genericRelation', 'méthode d’élaboration'),
#  ('texte de recommandations', 'genericRelation', 'document'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('messages-clés', 'genericRelation', 'méthode d’élaboration'),
#  ('messages-clés', 'partitiveRelation', 'recommandations'),
#  ('messages-clés', 'propertyRelation', 'format'),
#  ('fiches mémo', 'propertyRelation', 'qualité'),
#  ('fiches mémo', 'instrumentalRelation', 'sécurité'),
#  ('qualité', 'associativeRelation', 'sécurité'),
#  ('professionnel de santé', 'activityRelation', 'fiches mémo'),
#  ('discernement', 'activityRelation', 'prise en charge'),
#  ('discernement', 'associativeRelation', 'patient'),
#  ('patient', 'activityRelation', 'prise en charge'),
#  ('patient', 'activityRelation', 'appropriée'),
#  ('patient', 'activityRelation', 'constatations'),
#  ('constatations', 'originationRelation', 'préférences'),
#  ('préférences', 'associativeRelation', 'patient'),
#  ('fiche mémo', 'partitiveRelation', 'guide méthodologique'),
#  ('méthode', 'originationRelation', 'guide méthodologique'),
#  ('HAS', 'partitiveRelation', 'site'),
#  ('HAS', 'activityRelation', 'fiches mémo'),
#  ('Méthode d’élaboration', 'activityRelation', 'fiches mémo'),
#  ('Méthode d’élaboration', 'activityRelation', 'fiches pertinence'),
#  ('Grade', 'associativeRelation', 'recommandations'),
#  ('études', 'propertyRelation', 'niveau'),
#  ('essais comparatifs', 'genericRelation', 'études'),
#  ('randomisés', 'propertyRelation', 'puissance'),
#  ('randomisés', 'propertyRelation', 'biais majeur'),
#  ('randomisés', 'activityRelation', 'méta-analyse'),
#  ('randomisés', 'genericRelation', 'analyse de décision'),
#  ('puissance', 'associativeRelation', 'biais majeur'),
#  ('présomption scientifique', 'originationRelation', 'études'),
#  ('essais comparatifs', 'genericRelation', 'preuve'),
#  ('essais comparatifs', 'instrumentalRelation', 'randomisés'),
#  ('randomisés', 'genericRelation', 'preuve'),
#  ('puissance', 'genericRelation', 'preuve'),
#  ('études comparatives', 'propertyRelation', 'non randomisées'),
#  ('études de cohorte', 'partitiveRelation', 'non randomisées'),
#  ('preuve', 'propertyRelation', 'niveau'),
#  ('études', 'propertyRelation', 'niveau'),
#  ('études cas-témoins', 'genericRelation', 'études'),
#  ('études rétrospectives', 'genericRelation', 'études comparatives'),
#  ('études comparatives', 'partitiveRelation', 'séries'),
#  ('recommandations', 'originationRelation', 'experts'),
#  ('recommandations', 'originationRelation', 'groupe'),
#  ('experts', 'activityRelation', 'accord'),
#  ('experts', 'originationRelation', 'groupe'),
#  ('groupe', 'activityRelation', 'accord'),
#  ('consultation', 'activityRelation', 'AE de travail'),
#  ('groupe de lecture', 'activityRelation', 'AE de travail'),
#  ('groupe de lecture', 'activityRelation', 'consultation'),
#  ('adopté', 'activityRelation', 'document'),
#  ('Collège de la Haute Autorité de Santé', 'activityRelation', 'document'),
#  ('Collège de la Haute Autorité de Santé', 'activityRelation', 'adopté'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('acronymes', 'genericRelation', 'Abréviations'),
#  ('Données', 'originationRelation', 'recherche documentaire'),
#  ('recherche documentaire', 'genericRelation', 'recherche'),
#  ('recommandations', 'propertyRelation', 'Caractéristiques'),
#  ('recommandations', 'propertyRelation', 'méthodologiques'),
#  ('Définition', 'activityRelation', 'lombalgie commune'),
#  ('définition', 'activityRelation', 'lombalgie commune'),
#  ('lombalgie commune', 'genericRelation', 'douleur lombaire'),
#  ('Pistes', 'activityRelation', 'Définition; définition'),
#  ('Pistes', 'associativeRelation', 'lombalgie commune'),
#  ('Pistes', 'associativeRelation', 'non médicamenteuses'),
#  ('Prises', 'activityRelation', 'Définition; définition'),
#  ('Prises', 'associativeRelation', 'lombalgie commune'),
#  ('Prises', 'associativeRelation', 'non médicamenteuses'),
#  ('Prise en charge', 'genericRelation', 'Pistes; Prises'),
#  ('Prise en charge', 'associativeRelation', 'patient lombalgique'),
#  ('Prise en charge', 'associativeRelation', 'médicamenteuse'),
#  ('Évaluation clinique', 'genericRelation', 'Évaluation'),
#  ('Évaluation clinique', 'instrumentalRelation', 'recherche'),
#  ('Évaluation clinique', 'activityRelation', 'drapeaux'),
#  ('douleur lombaire', 'genericRelation', 'Pistes; Prises'),
#  ('douleur lombaire', 'associativeRelation', 'drapeaux'),
#  ('recherche', 'activityRelation', 'drapeaux'),
#  ('rouges', 'genericRelation', 'Pistes; Prises'),
#  ('Évaluation', 'activityRelation', 'risque'),
#  ('Pertinence', 'genericRelation', 'Évaluation'),
#  ('Prise en charge chirurgicale', 'genericRelation', 'Pistes; Prises'),
#  ('Aspects', 'associativeRelation', 'récidive de lombalgie'),
#  ('récidive de lombalgie', 'genericRelation', 'douleur lombaire'),
#  ('parties prenantes', 'activityRelation', 'Version soumise'),
#  ('Collège de la HAS', 'activityRelation', 'Adoption'),
#  ('HAS', 'genericRelation', 'acronymes'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'),
#  ('HAS', 'associativeRelation', 'non stéroïdiens'),
#  ('Anti-inflammatoires', 'genericRelation', 'acronymes'),
#  ('Anti-inflammatoires',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'),
#  ('Anti-inflammatoires', 'associativeRelation', 'non stéroïdiens'),
#  ('Caisse nationale de l’Assurance maladie', 'genericRelation', 'acronymes'),
#  ('Caisse nationale de l’Assurance maladie',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles; AINS; CNAM; Fiche descriptive; DGOS'),
#  ('Caisse nationale de l’Assurance maladie',
#   'associativeRelation',
#   'non stéroïdiens'),
#  ('Service des bonnes pratiques professionnelles',
#   'genericRelation',
#   'Références; Remerciements'),
#  ('AINS', 'genericRelation', 'Références; Remerciements'),
#  ('CNAM', 'genericRelation', 'Références; Remerciements'),
#  ('Fiche descriptive', 'genericRelation', 'Références; Remerciements'),
#  ('DGOS', 'genericRelation', 'Références; Remerciements'),
#  ('Prise', 'genericRelation', 'Références; Remerciements'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('Abréviations', 'genericRelation', 'Références; Remerciements'),
#  ('Abréviations', 'associativeRelation', 'acronymes'),
#  ('Direction générale', 'associativeRelation', 'soins'),
#  ('Practice', 'propertyRelation', 'Optimized'),
#  ('Practice', 'genericRelation', 'recommandations de bonne pratique'),
#  ('Practice', 'activityRelation', 'lombalgie commune'),
#  ('Hospital Anxiety and Depression', 'propertyRelation', 'Optimized'),
#  ('Hospital Anxiety and Depression',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Hospital Anxiety and Depression', 'activityRelation', 'lombalgie commune'),
#  ('Fear Avoidance Belief Questionnaire', 'propertyRelation', 'Optimized'),
#  ('Fear Avoidance Belief Questionnaire',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Fear Avoidance Belief Questionnaire',
#   'activityRelation',
#   'lombalgie commune'),
#  ('IRM', 'propertyRelation', 'Optimized'),
#  ('IRM', 'genericRelation', 'recommandations de bonne pratique'),
#  ('IRM', 'activityRelation', 'lombalgie commune'),
#  ('KCE', 'propertyRelation', 'Optimized'),
#  ('KCE', 'genericRelation', 'recommandations de bonne pratique'),
#  ('KCE', 'activityRelation', 'lombalgie commune'),
#  ('TENS', 'propertyRelation', 'Optimized'),
#  ('TENS', 'genericRelation', 'recommandations de bonne pratique'),
#  ('TENS', 'activityRelation', 'lombalgie commune'),
#  ('HAS', 'propertyRelation', 'Optimized'),
#  ('HAS', 'genericRelation', 'recommandations de bonne pratique'),
#  ('HAS', 'activityRelation', 'lombalgie commune'),
#  ('Imagerie par résonance magnétique', 'propertyRelation', 'Optimized'),
#  ('Imagerie par résonance magnétique',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Imagerie par résonance magnétique',
#   'activityRelation',
#   'lombalgie commune'),
#  ('Belgian Health Care Knowledge Centre', 'propertyRelation', 'Optimized'),
#  ('Belgian Health Care Knowledge Centre',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Belgian Health Care Knowledge Centre',
#   'activityRelation',
#   'lombalgie commune'),
#  ('National Institute for Health and Care Excellence',
#   'propertyRelation',
#   'Optimized'),
#  ('National Institute for Health and Care Excellence',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('National Institute for Health and Care Excellence',
#   'activityRelation',
#   'lombalgie commune'),
#  ('Transcutaneous Electrical Nerve Stimulation',
#   'propertyRelation',
#   'Optimized'),
#  ('Transcutaneous Electrical Nerve Stimulation',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Transcutaneous Electrical Nerve Stimulation',
#   'activityRelation',
#   'lombalgie commune'),
#  ('Service des bonnes pratiques professionnelles',
#   'propertyRelation',
#   'Optimized'),
#  ('Service des bonnes pratiques professionnelles',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Service des bonnes pratiques professionnelles',
#   'activityRelation',
#   'lombalgie commune'),
#  ('Caisse nationale de l’Assurance maladie', 'propertyRelation', 'Optimized'),
#  ('Caisse nationale de l’Assurance maladie',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Caisse nationale de l’Assurance maladie',
#   'activityRelation',
#   'lombalgie commune'),
#  ('Direction générale de l’offre de', 'propertyRelation', 'Optimized'),
#  ('Direction générale de l’offre de',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Direction générale de l’offre de', 'activityRelation', 'lombalgie commune'),
#  ('Haute Autorité de Santé', 'propertyRelation', 'Optimized'),
#  ('Haute Autorité de Santé',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('Haute Autorité de Santé', 'activityRelation', 'lombalgie commune'),
#  ('professionnels de santé', 'propertyRelation', 'Optimized'),
#  ('professionnels de santé',
#   'genericRelation',
#   'recommandations de bonne pratique'),
#  ('professionnels de santé', 'activityRelation', 'lombalgie commune'),
#  ('Saisine', 'propertyRelation', 'Optimized'),
#  ('Saisine', 'genericRelation', 'recommandations de bonne pratique'),
#  ('Saisine', 'activityRelation', 'lombalgie commune'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('recommandations de bonne pratique',
#   'associativeRelation',
#   'patient présentant'),
#  ('patient présentant', 'activityRelation', 'prise en charge'),
#  ('grand public', 'activityRelation', 'travail'),
#  ('grand public', 'activityRelation', 'sensibilisation'),
#  ('prise en charge', 'activityRelation', 'lombalgie commune'),
#  ('publications', 'activityRelation', 'recommandations'),
#  ('Centre fédéral d’expertise des soins de santé',
#   'genericRelation',
#   'internationales'),
#  ('soins français', 'associativeRelation', 'prescriptions'),
#  ('parcours', 'instrumentalRelation', 'prise en charge'),
#  ('parcours', 'activityRelation', 'lombalgie commune'),
#  ('prise en charge', 'activityRelation', 'lombalgie commune'),
#  ('lombalgie', 'genericRelation', 'problème'),
#  ('lombalgie', 'associativeRelation', 'santé publique'),
#  ('lombalgie', 'associativeRelation', 'santé'),
#  ('aiguë', 'associativeRelation', 'chronique'),
#  ('chronique', 'genericRelation', 'problème'),
#  ('chronique', 'associativeRelation', 'santé'),
#  ('problème', 'propertyRelation', 'santé publique'),
#  ('santé publique', 'associativeRelation', 'santé'),
#  ('patients', 'activityRelation', 'guérissent'),
#  ('patients', 'associativeRelation', 'lombalgie subaiguë'),
#  ('guérissent', 'associativeRelation', 'lombalgie subaiguë'),
#  ('données', 'originationRelation', 'patients'),
#  ('consultations', 'propertyRelation', 'résultats'),
#  ('consultations', 'activityRelation', 'prescriptions'),
#  ('prescriptions', 'propertyRelation', 'lignes de'),
#  ('médicamenteuses', 'propertyRelation', 'saisis en temps réel'),
#  ('généraliste français', 'activityRelation', 'patients'),
#  ('généraliste français', 'activityRelation', 'lombalgie'),
#  ('patients', 'associativeRelation', 'lombalgie'),
#  ('répartition', 'activityRelation', 'patients lombalgiques'),
#  ('patients lombalgiques', 'propertyRelation', 'tranche'),
#  ('hommes', 'associativeRelation', 'femmes'),
#  ('lombalgie', 'associativeRelation', 'patients'),
#  ('lombalgie', 'propertyRelation', 'prévalence'),
#  ('Handicap-Santé', 'associativeRelation', 'population'),
#  ('lieu de vie', 'spatialRelation', 'France'),
#  ('données', 'activityRelation', 'appariement'),
#  ("régimes de l'Assurance maladie-Sniiram", 'associativeRelation', 'recours'),
#  ('personnes', 'activityRelation', 'soins'),
#  ('personnes', 'activityRelation', 'dépenses de santé'),
#  ('extraites', 'originationRelation', 'enquête'),
#  ('extraites', 'originationRelation', 'population française'),
#  ('sujets', 'partitiveRelation', 'enquête'),
#  ('sujets', 'partitiveRelation', 'population française'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('données', 'originationRelation', 'réseau'),
#  ('données', 'originationRelation', 'OSCOUR®'),
#  ('OSCOUR®', 'genericRelation', 'réseau'),
#  ('structures d’urgences', 'activityRelation', 'recours'),
#  ('passages', 'spatialRelation', 'urgences'),
#  ('urgences', 'associativeRelation', 'lombalgie commune'),
#  ('lombalgie', 'genericRelation', 'diagnostic principal'),
#  ('codée', 'activityRelation', 'lombalgie'),
#  ('passages', 'spatialRelation', 'période'),
#  ('causes codées', 'associativeRelation', 'code diagnostic'),
#  ('passages', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'associativeRelation', 'hospitalisation'),
#  ('lombalgie', 'associativeRelation', 'taux'),
#  ('hospitalisation', 'associativeRelation', 'taux'),
#  ('État', 'activityRelation', 'pratiques'),
#  ('État', 'activityRelation', 'prise en charge'),
#  ('pratiques', 'activityRelation', 'prise en charge'),
#  ('radiographie du dos', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'associativeRelation', 'patients'),
#  ('recommandé', 'associativeRelation', 'drapeaux rouges'),
#  ('arrêt maladie', 'associativeRelation', 'lombalgie'),
#  ('patients', 'activityRelation', 'kinésithérapie'),
#  ('rhumatologue', 'activityRelation', 'consulté'),
#  ('interventionnelles', 'genericRelation', 'Alternatives'),
#  ('prises en charge', 'associativeRelation', 'non médicamenteuses'),
#  ('techniques ma', 'genericRelation', 'prises en charge'),
#  ('nuelles', 'associativeRelation', 'interventions psychologiques'),
#  ('ceintures', 'partitiveRelation', 'nuelles'),
#  ('ceintures', 'genericRelation', 'interventions psychologiques'),
#  ('semelles orthopédiques', 'partitiveRelation', 'nuelles'),
#  ('semelles orthopédiques', 'genericRelation', 'interventions psychologiques'),
#  ('tractions', 'partitiveRelation', 'nuelles'),
#  ('tractions', 'genericRelation', 'interventions psychologiques'),
#  ('acupuncture', 'genericRelation', 'TENS)'),
#  ('relaxation', 'genericRelation', 'TENS)'),
#  ('charges et produits', 'partitiveRelation', 'rapport annuel'),
#  ('recours', 'activityRelation', 'médecin traitant'),
#  ('recours', 'activityRelation', 'Français'),
#  ('médecin traitant', 'associativeRelation', 'lombalgie chronique'),
#  ('lombalgie chronique', 'associativeRelation', 'Français'),
#  ('lombalgie', 'associativeRelation', 'arrêt de travail'),
#  ('arrêts de travail', 'partitiveRelation', 'accidents du travail'),
#  ('pratiques', 'associativeRelation', 'freins'),
#  ('pratiques', 'associativeRelation', 'fausses'),
#  ('fausses', 'genericRelation', 'freins'),
#  ('croyances', 'originationRelation', 'professionnels de santé; patients)'),
#  ('peurs', 'genericRelation', 'croyances'),
#  ('peurs', 'associativeRelation', 'professionnels de santé; patients)'),
#  ('travail)', 'genericRelation', 'activités'),
#  ('signes d’alerte', 'associativeRelation', 'facteurs'),
#  ('signes d’alerte', 'associativeRelation', 'évolution chronique'),
#  ('facteurs', 'associativeRelation', 'évolution chronique'),
#  ('recommandation', 'instrumentalRelation', 'bonne pratique'),
#  ('bonne pratique', 'instrumentalRelation', 'Santé et maintien en emploi'),
#  ('Santé et maintien en emploi', 'partitiveRelation', 'recommandation'),
#  ('partenariat', 'originationRelation', 'HAS/SFMT'),
#  ('pathologies', 'associativeRelation', 'RBP'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('définition', 'activityRelation', 'lombalgie commune'),
#  ('lombalgie commune', 'genericRelation', 'signes d’alerte'),
#  ('signes d’alerte',
#   'genericRelation',
#   'thérapies cognitivo-comportementales'),
#  ('signes d’alerte', 'associativeRelation', 'facteurs'),
#  ('signes d’alerte', 'associativeRelation', 'évolution chronique'),
#  ('facteurs', 'associativeRelation', 'évolution chronique'),
#  ('risque', 'associativeRelation', 'chronicité'),
#  ('pertinence', 'genericRelation', 'aspects'),
#  ('rééducation', 'genericRelation', 'thérapies cognitivo-comportementales'),
#  ('facettaires', 'genericRelation', 'infiltrations'),
#  ('facettaires', 'associativeRelation', 'hiatus saccrococcygien; TENS'),
#  ('hiatus saccrococcygien', 'genericRelation', 'thérapies psychologiques'),
#  ('TENS', 'genericRelation', 'thérapies psychologiques'),
#  ('reprise', 'activityRelation', 'activités quotidiennes'),
#  ('auto-gestion', 'genericRelation', 'thérapies psychologiques'),
#  ('techniques manuelles',
#   'genericRelation',
#   'thérapies cognitivo-comportementales'),
#  ('mobilisations)', 'genericRelation', 'techniques manuelles'),
#  ('semelles orthopédiques', 'genericRelation', 'thérapies psychologiques'),
#  ('tractions manuelles',
#   'genericRelation',
#   'thérapies cognitivo-comportementales'),
#  ('thérapies posturales', 'genericRelation', 'thérapie'),
#  ('acupuncture', 'genericRelation', 'thérapies psychologiques'),
#  ('thérapies physiques', 'genericRelation', 'thérapie'),
#  ('chaleur', 'genericRelation', 'facteurs'),
#  ('taping)', 'genericRelation', 'thérapies physiques'),
#  ('Yoga', 'genericRelation', 'sports'),
#  ('Tai Chi', 'genericRelation', 'sports'),
#  ('Chi Qong)', 'genericRelation', 'facteurs'),
#  ('relaxation', 'genericRelation', 'thérapies physiques'),
#  ('sophrologie', 'genericRelation', 'thérapies physiques'),
#  ('hypnose', 'genericRelation', 'thérapies physiques'),
#  ('hypnose', 'partitiveRelation', 'sophrologie'),
#  ('thérapies psychologiques', 'genericRelation', 'thérapies physiques'),
#  ('thérapies cognitivo-comportementales',
#   'genericRelation',
#   'thérapies physiques'),
#  ('thérapie', 'genericRelation', 'thérapies psychologiques'),
#  ('aspects', 'associativeRelation', 'prévention secondaire'),
#  ('aspects', 'associativeRelation', 'lombalgie'),
#  ('prévention secondaire', 'activityRelation', 'récidive'),
#  ('prévention secondaire', 'associativeRelation', 'lombalgie'),
#  ('récidive', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'genericRelation', 'signes d’alerte'),
#  ('maintien en emploi', 'genericRelation', 'champ'),
#  ('maintien en emploi', 'associativeRelation', 'recommandations'),
#  ('champ', 'partitiveRelation', 'recommandations'),
#  ('Patients concernés', 'associativeRelation', 'thème'),
#  ('recommandations', 'associativeRelation', 'patients'),
#  ('recommandations', 'associativeRelation', 'lombalgie commune'),
#  ('patients', 'propertyRelation', 'lombalgie commune'),
#  ('douleurs lombaires ou radiculaires',
#   'associativeRelation',
#   'pathologie sous-jacente'),
#  ('tumeur', 'associativeRelation', 'ostéoporose'),
#  ('tumeur', 'associativeRelation', 'maladie'),
#  ('ostéoporose', 'associativeRelation', 'fracture'),
#  ('ostéoporose', 'associativeRelation', 'déformation structurelle'),
#  ('ostéoporose', 'genericRelation', 'maladie'),
#  ('fracture', 'associativeRelation', 'maladie'),
#  ('déformation structurelle', 'genericRelation', 'fracture'),
#  ('déformation structurelle', 'associativeRelation', 'maladie'),
#  ('inflammatoire',
#   'associativeRelation',
#   'syndrome de queue de cheval; maladie neurologique grave)'),
#  ('champ', 'activityRelation', 'recommandations'),
#  ('Professionnels', 'activityRelation', 'thème'),
#  ('recommandations', 'originationRelation', 'médecins généralistes'),
#  ('recommandations', 'associativeRelation', 'rhumatologues'),
#  ('recommandations', 'originationRelation', 'médecins de'),
#  ('médecins généralistes', 'genericRelation', 'médecins de'),
#  ('rhumatologues',
#   'genericRelation',
#   'kinésithérapeutes; médecins de la douleur'),
#  ('médecins de', 'genericRelation', 'Professionnels'),
#  ('médecine physique et de réadaptation', 'genericRelation', 'médecins de'),
#  ('médecins du travail', 'genericRelation', 'médecins de'),
#  ('chirurgiens du rachis',
#   'genericRelation',
#   'médecine physique et de réadaptation; médecins du travail'),
#  ('masseurs',
#   'genericRelation',
#   'médecine physique et de réadaptation; médecins du travail'),
#  ('kinésithérapeutes', 'genericRelation', 'Professionnels'),
#  ('médecins de la douleur', 'genericRelation', 'Professionnels'),
#  ('radiologues', 'genericRelation', 'médecins de'),
#  ('psychologues', 'genericRelation', 'médecins de'),
#  ('ostéopathes', 'genericRelation', 'Professionnels'),
#  ('chiropracteurs', 'genericRelation', 'médecins de'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('Données', 'originationRelation', 'recherche documentaire'),
#  ('Caractéristiques', 'partitiveRelation', 'rapport'),
#  ('méthodologiques', 'partitiveRelation', 'rapport'),
#  ('recommandations', 'propertyRelation', 'Caractéristiques'),
#  ('recommandations', 'propertyRelation', 'méthodologiques'),
#  ('recommandations', 'partitiveRelation', 'rapport'),
#  ('Caractéristiques', 'partitiveRelation', 'rapport'),
#  ('recommandations', 'genericRelation', 'guidelines'),
#  ('recommandations', 'propertyRelation', 'Caractéristiques'),
#  ('recommandations', 'partitiveRelation', 'rapport'),
#  ('Méthodologie', 'genericRelation', 'soins de santé'),
#  ('Indépen', 'genericRelation', 'recommandations'),
#  ('Promoteur', 'activityRelation', 'dance'),
#  ('Stratégie de Pluridisciplinarité',
#   'genericRelation',
#   'Guide de pratique clinique'),
#  ('Stratégie de Pluridisciplinarité', 'associativeRelation', 'dance'),
#  ('ADAPTE', 'genericRelation', 'Guide de pratique clinique'),
#  ('ADAPTE', 'associativeRelation', 'dance'),
#  ('NICE', 'genericRelation', 'Guide de pratique clinique'),
#  ('NICE', 'associativeRelation', 'dance'),
#  ('Titre', 'genericRelation', 'guidelines'),
#  ('Titre', 'associativeRelation', 'Limites'),
#  ('Champs', 'partitiveRelation', 'Titre'),
#  ('Champs', 'associativeRelation', 'Limites'),
#  ('objectifs', 'partitiveRelation', 'Titre'),
#  ('objectifs', 'genericRelation', 'Champs'),
#  ('Limites', 'genericRelation', 'guidelines'),
#  ('gradation', 'genericRelation', 'objectifs'),
#  ('gradation', 'associativeRelation', 'éditoriale'),
#  ('documentaire', 'genericRelation', 'objectifs'),
#  ('Guide de pratique clinique', 'genericRelation', 'guidelines'),
#  ('douleurs lombaires', 'genericRelation', 'soins de santé'),
#  ('guidelines', 'associativeRelation', 'Drapeaux rouges'),
#  ('Drapeaux rouges', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'genericRelation', 'douleurs lombaires'),
#  ('radiculaires GRADE', 'genericRelation', 'gradation'),
#  ('Low back pain', 'genericRelation', 'pain'),
#  ('Low back pain', 'associativeRelation', 'sciatica; sciatique'),
#  ('sciatica', 'genericRelation', 'pain'),
#  ('sciatique', 'genericRelation', 'pain'),
#  ('Care Excellence', 'associativeRelation', 'biblio'),
#  ('biblio', 'activityRelation', 'National Clinical Guidelines'),
#  ('biblio', 'associativeRelation', 'interventions'),
#  ('assessment and Méthode', 'partitiveRelation', 'Care Excellence'),
#  ('assessment and Méthode', 'genericRelation', 'biblio'),
#  ('lombalgie', 'genericRelation', 'pain'),
#  ('lombalgie', 'associativeRelation', 'Oui Oui'),
#  ('Oui Oui', 'genericRelation', 'Évaluation'),
#  ('management GRADE', 'genericRelation', 'GRADE'),
#  ('Royaume-Uni', 'genericRelation', 'onset'),
#  ('interventions', 'partitiveRelation', 'National Clinical Guidelines'),
#  ('non-surgical treatment', 'genericRelation', 'interventions'),
#  ('non-surgical treatment', 'activityRelation', 'chirurgicales'),
#  ('lombo- patients lombalgie non spécifique Méthode',
#   'genericRelation',
#   'assessment and Méthode'),
#  ('Danemark radiculalgie', 'genericRelation', 'lombalgie'),
#  ('Danemark radiculalgie', 'propertyRelation', 'low back'),
#  ('Danemark radiculalgie', 'propertyRelation', 'GRADE'),
#  ('onset', 'activityRelation', 'GRADE'),
#  ('GRADE', 'propertyRelation', 'low back'),
#  ('pain', 'associativeRelation', 'lumbar radiculopathy'),
#  ('pain', 'associativeRelation', 'radiculopathie lombaire'),
#  ('lumbar radiculopathy', 'genericRelation', 'interventions'),
#  ('lumbar radiculopathy', 'associativeRelation', 'radiculopathie lombaire'),
#  ('lombalgie', 'genericRelation', 'radiculopathie'),
#  ('subaiguë', 'genericRelation', 'aiguë'),
#  ('Noninvasive treatments', 'genericRelation', 'traitements'),
#  ('Physicians', 'associativeRelation', 'chronic'),
#  ('Physicians', 'activityRelation', 'Élaborer des'),
#  ('Physicians', 'activityRelation', 'ACP Guideline'),
#  ('subacute', 'genericRelation', 'Physicians'),
#  ('subacute', 'associativeRelation', 'chronic'),
#  ('subacute', 'associativeRelation', 'Élaborer des'),
#  ('subacute', 'associativeRelation', 'ACP Guideline'),
#  ('chronic', 'associativeRelation', 'Élaborer des'),
#  ('Élaborer des', 'activityRelation', 'ACP Guideline'),
#  ('ACP Guideline', 'genericRelation', 'practice guideline'),
#  ('ACP Guideline', 'propertyRelation', 'chronic'),
#  ('low back pain', 'genericRelation', 'chronic'),
#  ('low back pain', 'associativeRelation', 'NP Grading Oui'),
#  ('clinical recommandations', 'associativeRelation', 'NP Grading Oui'),
#  ('clinical recommandations', 'genericRelation', 'Promoteur'),
#  ('clinical recommandations',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('clinical recommandations', 'associativeRelation', 'dance'),
#  ('American College', 'associativeRelation', 'NP Grading Oui'),
#  ('American College', 'genericRelation', 'Promoteur'),
#  ('American College',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('American College', 'associativeRelation', 'dance'),
#  ('lombalgie aiguë', 'associativeRelation', 'NP Grading Oui'),
#  ('lombalgie aiguë', 'genericRelation', 'Promoteur'),
#  ('lombalgie aiguë',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('lombalgie aiguë', 'associativeRelation', 'dance'),
#  ('HAS', 'associativeRelation', 'NP Grading Oui'),
#  ('HAS', 'genericRelation', 'Promoteur'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('HAS', 'associativeRelation', 'dance'),
#  ('Stratégie de Pluridisciplinarité', 'associativeRelation', 'NP Grading Oui'),
#  ('Stratégie de Pluridisciplinarité', 'genericRelation', 'Promoteur'),
#  ('Stratégie de Pluridisciplinarité',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Stratégie de Pluridisciplinarité', 'associativeRelation', 'dance'),
#  ('American College of lombalgie aiguë',
#   'associativeRelation',
#   'NP Grading Oui'),
#  ('American College of lombalgie aiguë', 'genericRelation', 'Promoteur'),
#  ('American College of lombalgie aiguë',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('American College of lombalgie aiguë', 'associativeRelation', 'dance'),
#  ('Physicians chronique', 'associativeRelation', 'NP Grading Oui'),
#  ('Physicians chronique', 'genericRelation', 'Promoteur'),
#  ('Physicians chronique',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Physicians chronique', 'associativeRelation', 'dance'),
#  ('GRADE', 'associativeRelation', 'NP Grading Oui'),
#  ('GRADE', 'genericRelation', 'Promoteur'),
#  ('GRADE',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('GRADE', 'associativeRelation', 'dance'),
#  ('NP Grading Oui', 'genericRelation', 'practice guideline'),
#  ('practice guideline', 'spatialRelation', 'Etats-Unis; États-Unis'),
#  ('practice guideline', 'spatialRelation', 'traitements'),
#  ('practice guideline', 'partitiveRelation', 'System(*)'),
#  ('traitements', 'spatialRelation', 'Etats-Unis; États-Unis'),
#  ('traitements', 'originationRelation', 'System(*)'),
#  ('System(*)', 'spatialRelation', 'Etats-Unis; États-Unis'),
#  ('System(*)', 'propertyRelation', 'non-invasifs'),
#  ('Service des bonnes pratiques professionnelles',
#   'genericRelation',
#   'objectifs'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('lombalgie commune', 'genericRelation', 'lombalgie'),
#  ('Indépen', 'genericRelation', 'Méthodologie'),
#  ('Promoteur', 'activityRelation', 'dance'),
#  ('Titre', 'genericRelation', 'subaiguë'),
#  ('Titre', 'associativeRelation', 'Limites'),
#  ('Champs', 'partitiveRelation', 'Titre'),
#  ('Champs', 'associativeRelation', 'Limites'),
#  ('objectifs', 'partitiveRelation', 'Titre'),
#  ('objectifs', 'genericRelation', 'Champs'),
#  ('gradation', 'genericRelation', 'objectifs'),
#  ('gradation', 'associativeRelation', 'éditoriale'),
#  ('documentaire', 'genericRelation', 'objectifs'),
#  ('pourcentage', 'genericRelation', 'objectifs'),
#  ('radiculopathie', 'genericRelation', 'traitements'),
#  ('imagerie', 'genericRelation', 'traitements'),
#  ('Clinical Systems', 'genericRelation', 'System(*)'),
#  ('prescrite', 'activityRelation', 'Clinical Systems'),
#  ('Improvement', 'activityRelation', 'Adult acute'),
#  ('Improvement', 'activityRelation', 'low drapeaux rouges'),
#  ('Adult acute', 'genericRelation', 'aiguë'),
#  ('back pain consultation', 'genericRelation', 'traitements'),
#  ('prescription d’opioïdes', 'genericRelation', 'traitements'),
#  ('lombalgie chronique', 'genericRelation', 'Limites'),
#  ('Evidence-informed', 'propertyRelation', 'Optimized'),
#  ('primary', 'propertyRelation', 'Optimized'),
#  ('primary', 'propertyRelation', 'Evidence-informed'),
#  ('Practice', 'instrumentalRelation', 'care management'),
#  ('Lombalgie', 'genericRelation', 'methods'),
#  ('Lombalgie', 'propertyRelation', 'Non-specific'),
#  ('low back pain', 'genericRelation', 'methods'),
#  ('low back pain', 'propertyRelation', 'Non-specific'),
#  ('Prise',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('lombalgie commune', 'genericRelation', 'Lombalgie'),
#  ('A Measurement Tool to Assess Systematic Reviews',
#   'genericRelation',
#   'methods'),
#  ('Grading of', 'genericRelation', 'methods'),
#  ('Recommendations Assessment, Development and Evaluation',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('Recommendations Assessment, Development and Evaluation',
#   'associativeRelation',
#   'Grading of'),
#  ('Recommendations Assessment, Development and Evaluation',
#   'activityRelation',
#   'systematic reviews'),
#  ('NICE',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('NICE', 'associativeRelation', 'Grading of'),
#  ('NICE', 'activityRelation', 'systematic reviews'),
#  ('Clinical Practice',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('Clinical Practice', 'associativeRelation', 'Grading of'),
#  ('Clinical Practice', 'activityRelation', 'systematic reviews'),
#  ('HAS', 'genericRelation', 'A Measurement Tool to Assess Systematic Reviews'),
#  ('HAS', 'associativeRelation', 'Grading of'),
#  ('HAS', 'activityRelation', 'systematic reviews'),
#  ('Service des bonnes pratiques professionnelles',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('Service des bonnes pratiques professionnelles',
#   'associativeRelation',
#   'Grading of'),
#  ('Service des bonnes pratiques professionnelles',
#   'activityRelation',
#   'systematic reviews'),
#  ('NP', 'genericRelation', 'A Measurement Tool to Assess Systematic Reviews'),
#  ('NP', 'associativeRelation', 'Grading of'),
#  ('NP', 'activityRelation', 'systematic reviews'),
#  ('AHRQ',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('AHRQ', 'associativeRelation', 'Grading of'),
#  ('AHRQ', 'activityRelation', 'systematic reviews'),
#  ('National Institute for Health and Care Excellence',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('National Institute for Health and Care Excellence',
#   'associativeRelation',
#   'Grading of'),
#  ('National Institute for Health and Care Excellence',
#   'activityRelation',
#   'systematic reviews'),
#  ('Cochrane Back Review Group',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('Cochrane Back Review Group', 'associativeRelation', 'Grading of'),
#  ('Cochrane Back Review Group', 'activityRelation', 'systematic reviews'),
#  ('AMSTAR',
#   'genericRelation',
#   'A Measurement Tool to Assess Systematic Reviews'),
#  ('AMSTAR', 'associativeRelation', 'Grading of'),
#  ('AMSTAR', 'activityRelation', 'systematic reviews'),
#  ('classification', 'genericRelation', 'methods'),
#  ('GRADE working group', 'activityRelation', 'classification'),
#  ('GRADE working group', 'activityRelation', 'trials'),
#  ('GRADE working group', 'activityRelation', 'methods'),
#  ('trials', 'propertyRelation', 'randomized'),
#  ('methods', 'originationRelation', 'ACP grading system'),
#  ('methods', 'propertyRelation', 'randomized'),
#  ('recommandations', 'associativeRelation', 'revues'),
#  ('recommandations', 'originationRelation', 'littérature'),
#  ('recommandations', 'partitiveRelation', 'rapport'),
#  ('recommandations',
#   'originationRelation',
#   'comité consultatif d’Amérique latine'),
#  ('recommandations',
#   'associativeRelation',
#   'recherche bibliographique complémentaire'),
#  ('recommandations', 'associativeRelation', 'sujets'),
#  ('recommandations', 'originationRelation', 'auteur unique'),
#  ('revues', 'genericRelation', 'sujets'),
#  ('revues', 'partitiveRelation', 'littérature'),
#  ('revues', 'partitiveRelation', 'rapport'),
#  ('littérature', 'partitiveRelation', 'rapport'),
#  ('rapport', 'genericRelation', 'méthode d’élaboration'),
#  ('revue systématique canadienne', 'genericRelation', 'revues'),
#  ('recherche bibliographique complémentaire',
#   'genericRelation',
#   'méthode d’élaboration'),
#  ('italiennes', 'activityRelation', 'Pain in Neuro rehabilitation'),
#  ('italiennes', 'activityRelation', 'sujets'),
#  ('Pain in Neuro rehabilitation', 'genericRelation', 'méthode d’élaboration'),
#  ('Pain in Neuro rehabilitation', 'associativeRelation', 'sujets'),
#  ('lombalgie post-chirurgicale', 'genericRelation', 'méthode d’élaboration'),
#  ('lombalgie post-chirurgicale', 'associativeRelation', 'céphalées'),
#  ('lombalgie post-chirurgicale', 'associativeRelation', 'douleurs faciales'),
#  ('céphalées', 'genericRelation', 'douleurs myofasciales'),
#  ('céphalées', 'associativeRelation', 'fibromyalgie'),
#  ('douleurs faciales', 'genericRelation', 'douleurs myofasciales'),
#  ('douleurs faciales', 'associativeRelation', 'fibromyalgie'),
#  ('douleurs ostéoarticulaires', 'genericRelation', 'douleurs périnéales'),
#  ('douleurs ostéoarticulaires', 'associativeRelation', 'fibromyalgie'),
#  ('douleurs myofasciales', 'genericRelation', 'méthode d’élaboration'),
#  ('fibromyalgie', 'genericRelation', 'douleurs myofasciales'),
#  ('douleurs périnéales', 'genericRelation', 'douleurs faciales'),
#  ('auteur unique', 'activityRelation', 'méthode d’élaboration'),
#  ('revue systématique allemande', 'genericRelation', 'revues'),
#  ('prises en charge psychologiques', 'associativeRelation', 'lombalgie'),
#  ('descriptive', 'associativeRelation', 'évaluation'),
#  ('évaluation', 'associativeRelation', 'formulation'),
#  ('évaluation', 'associativeRelation', 'conclusion'),
#  ('formulation', 'activityRelation', 'conclusion'),
#  ('Rapid Response Report/reference list', 'genericRelation', 'formats'),
#  ('Canadian Agency for drugs and technology in health',
#   'genericRelation',
#   'formats'),
#  ('descriptifs', 'associativeRelation', 'évaluation'),
#  ('recommandations', 'originationRelation', 'Department of Veterans Affairs'),
#  ('recommandations', 'originationRelation', 'Department of Defense'),
#  ('recommandations', 'originationRelation', 'malaisiennes'),
#  ('recommandations',
#   'originationRelation',
#   'Malaysian Association Spine Society for the Study of Pain; Spine Society'),
#  ('Department of Veterans Affairs',
#   'associativeRelation',
#   'Department of Defense'),
#  ('malaisiennes',
#   'originationRelation',
#   'Malaysian Association Spine Society for the Study of Pain; Spine Society'),
#  ('Malaysia', 'associativeRelation', 'liens d’intérêts'),
#  ('liens d’intérêts', 'originationRelation', 'laboratoire Pfizer)'),
#  ('laboratoire Pfizer)', 'activityRelation', 'méthode d’élaboration'),
#  ('Synthèse', 'activityRelation', 'recommandations'),
#  ('Synthèse', 'activityRelation', 'définition'),
#  ('Synthèse', 'activityRelation', 'lombalgie commune'),
#  ('recommandations', 'instrumentalRelation', 'définition'),
#  ('définition', 'activityRelation', 'lombalgie commune'),
#  ('Recommandation', 'associativeRelation', 'Méthodologie Pays'),
#  ('Centre fédéral', 'associativeRelation', 'douleur lombaire'),
#  ('soins de santé', 'spatialRelation', 'radiculaire'),
#  ('soins de santé', 'genericRelation', 'douleur'),
#  ('radiculaire', 'associativeRelation', 'douleur'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('Recommandation', 'associativeRelation', 'Méthodologie Pays'),
#  ('patients', 'associativeRelation', 'lombalgie'),
#  ('issues', 'propertyRelation', 'isolée'),
#  ('douleurs radiculaires', 'associativeRelation', 'composante'),
#  ('guidelines', 'associativeRelation', 'neuropathique'),
#  ('guidelines', 'associativeRelation', 'douleur provoquée'),
#  ('neuropathique', 'associativeRelation', 'douleur provoquée'),
#  ('radiculaires', 'associativeRelation', 'sciatique)'),
#  ('sciatique)', 'associativeRelation', 'version'),
#  ('National Institute', 'associativeRelation', 'douleur lombaire'),
#  ('formulation', 'activityRelation', 'questions'),
#  ('formulation', 'activityRelation', 'guide'),
#  ('formulation', 'activityRelation', 'terme'),
#  ('formulation', 'activityRelation', 'lombalgie non spécifique'),
#  ('questions', 'associativeRelation', 'lombalgie non spécifique'),
#  ('guide', 'associativeRelation', 'lombalgie non spécifique'),
#  ('lombalgie non spécifique', 'genericRelation', 'terme'),
#  ('Care Excellence', 'associativeRelation', 'uniformité'),
#  ('Care Excellence', 'associativeRelation', 'lombalgie'),
#  ('uniformité', 'associativeRelation', 'lombalgie'),
#  ('guide définitif', 'partitiveRelation', 'Care Excellence'),
#  ('guide définitif', 'activityRelation', 'lombalgie'),
#  ('sciatique', 'genericRelation', 'douleur neuropathique irradiant'),
#  ('sciatique', 'associativeRelation', 'membres'),
#  ('compression', 'activityRelation', 'racines lombo-sacrées'),
#  ('lombalgies', 'partitiveRelation', 'College of'),
#  ('lombalgies', 'propertyRelation', 'aiguës'),
#  ('aiguës', 'partitiveRelation', 'College of'),
#  ('subaiguës', 'partitiveRelation', 'College of'),
#  ('subaiguës', 'partitiveRelation', 'lombalgies'),
#  ('subaiguës', 'genericRelation', 'aiguës'),
#  ('biblio', 'spatialRelation', 'États-Unis'),
#  ('biblio', 'associativeRelation', 'recommandations'),
#  ('biblio', 'propertyRelation', 'catégories'),
#  ('recommandations', 'spatialRelation', 'États-Unis'),
#  ('recommandations', 'propertyRelation', 'catégories'),
#  ('Clinical Systems', 'spatialRelation', 'États-Unis'),
#  ('Lombalgie', 'genericRelation', 'douleur'),
#  ('Lombalgie', 'spatialRelation', 'cage'),
#  ('douleur lombaire', 'genericRelation', 'douleur'),
#  ('douleur lombaire', 'spatialRelation', 'cage'),
#  ('aiguë', 'genericRelation', 'Lombalgie; douleur lombaire'),
#  ('subaiguë', 'genericRelation', 'aiguë'),
#  ('subaiguë', 'associativeRelation', 'chronique'),
#  ('chronique', 'genericRelation', 'Lombalgie; douleur lombaire'),
#  ('douleur', 'spatialRelation', 'cage'),
#  ('tension musculaire', 'genericRelation', 'douleur'),
#  ('tension musculaire', 'spatialRelation', 'cage'),
#  ('raideur', 'genericRelation', 'douleur'),
#  ('raideur', 'partitiveRelation', 'Lombalgie; douleur lombaire'),
#  ('raideur', 'spatialRelation', 'cage'),
#  ('Toward', 'propertyRelation', 'douleur de jambe'),
#  ('Toward', 'propertyRelation', 'cause'),
#  ('thoracique', 'partitiveRelation', 'Toward'),
#  ('thoracique', 'propertyRelation', 'cause'),
#  ('pli fessier inférieur', 'partitiveRelation', 'Toward'),
#  ('pli fessier inférieur', 'partitiveRelation', 'thoracique'),
#  ('pli fessier inférieur', 'propertyRelation', 'cause'),
#  ('douleur de jambe', 'genericRelation', 'Lombalgie; douleur lombaire'),
#  ('douleur de jambe', 'propertyRelation', 'cause'),
#  ('Optimized', 'activityRelation', 'Canada'),
#  ('guide', 'associativeRelation', 'douleurs lombaires aiguës/subaiguës'),
#  ('guide', 'associativeRelation', 'lombalgies chroniques'),
#  ('douleurs lombaires aiguës/subaiguës',
#   'associativeRelation',
#   'lombalgies chroniques'),
#  ('Allemagne', 'associativeRelation', 'Absence de définition'),
#  ('lombalgie', 'spatialRelation', 'Allemagne'),
#  ('lombalgie', 'propertyRelation', 'Absence de définition'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('Méta-analyse', 'genericRelation', 'tests'),
#  ('Méta-analyse', 'activityRelation', 'définition'),
#  ('Méta-analyse', 'activityRelation', 'lombalgie'),
#  ('définition', 'activityRelation', 'lombalgie'),
#  ('lombalgie', 'genericRelation', 'syndrome'),
#  ('documentaire', 'genericRelation', 'articles'),
#  ('date', 'genericRelation', 'articles'),
#  ('Critères de sélection', 'genericRelation', 'tests'),
#  ('Critères de sélection', 'propertyRelation', 'documentaire; date'),
#  ('Auteurs', 'associativeRelation', 'année'),
#  ('Auteurs', 'associativeRelation', 'Question'),
#  ('année', 'genericRelation', 'documentaire; date'),
#  ('Question', 'genericRelation', 'tests'),
#  ('Question', 'partitiveRelation', 'année'),
#  ('recherche limite', 'genericRelation', 'documentaire; date'),
#  ('recherche limite', 'associativeRelation', 'qualité'),
#  ('recherche limite', 'associativeRelation', 'articles'),
#  ('articles', 'propertyRelation', 'qualité'),
#  ('articles', 'propertyRelation', 'signification'),
#  ('Critères de jugement', 'genericRelation', 'tests'),
#  ('Évaluation', 'genericRelation', 'tests'),
#  ('Études', 'genericRelation', 'articles'),
#  ('prospectives', 'genericRelation', 'Études'),
#  ('rétrospectives', 'genericRelation', 'Études'),
#  ('rétrospectives', 'activityRelation', 'syndrome'),
#  ('Medline', 'genericRelation', 'documentaire; date'),
#  ('EMBASE', 'genericRelation', 'documentaire; date'),
#  ('CINAHL', 'genericRelation', 'tests'),
#  ('Web', 'partitiveRelation', 'CINAHL'),
#  ('stratégie clinique', 'associativeRelation', 'test'),
#  ('données', 'propertyRelation', 'hétérogènes'),
#  ('Cochrane poolées', 'partitiveRelation', 'Scholar'),
#  ('recours', 'activityRelation', 'bloc anesthésique'),
#  ('Patients', 'propertyRelation', 'technique de référence'),
#  ('Synthèse', 'associativeRelation', 'lombalgie'),
#  ('Synthèse', 'associativeRelation', 'recommandations'),
#  ('lombalgie', 'associativeRelation', 'recommandations'),
#  ('définie', 'activityRelation', 'douleur'),
#  ('douleur', 'propertyRelation', 'localisation'),
#  ('cage thoracique', 'partitiveRelation', 'littérature'),
#  ('pli fessier inférieur', 'partitiveRelation', 'cage thoracique'),
#  ('pli fessier inférieur', 'partitiveRelation', 'littérature'),
#  ('canadienne', 'propertyRelation', 'tension musculaire'),
#  ('canadienne', 'activityRelation', 'raideur'),
#  ('douleur', 'associativeRelation', 'tension musculaire'),
#  ('douleur', 'associativeRelation', 'raideur'),
#  ('tension musculaire', 'associativeRelation', 'raideur'),
#  ('revue', 'activityRelation', 'définition'),
#  ('revue', 'activityRelation', 'lombalgie'),
#  ('définition', 'propertyRelation', 'systématique'),
#  ('lombalgie', 'propertyRelation', 'systématique'),
#  ('lombalgie', 'propertyRelation', 'définition'),
#  ('guide belge', 'propertyRelation', 'version française'),
#  ('douleur lombaire', 'associativeRelation', 'version française'),
#  ('douleur lombaire', 'associativeRelation', 'guide belge'),
#  ('lombalgie', 'associativeRelation', 'version française'),
#  ('lombalgie', 'associativeRelation', 'guide belge'),
#  ('terme', 'partitiveRelation', 'littérature'),
#  ('non-specific low back pain', 'genericRelation', 'terme'),
#  ('non-specific low back pain', 'partitiveRelation', 'littérature'),
#  ('données', 'originationRelation', 'littérature'),
#  ('interprétation', 'activityRelation', 'terminologie'),
#  ('lombalgie', 'associativeRelation', 'recommandation britannique'),
#  ('lombalgie non spécifique',
#   'associativeRelation',
#   'recommandation britannique'),
#  ('littérature', 'activityRelation', 'sous-type'),
#  ('littérature', 'associativeRelation', 'lombalgie'),
#  ('littérature', 'associativeRelation', 'syndrome facettaire)'),
#  ('sous-type', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'associativeRelation', 'syndrome facettaire)'),
#  ('syndrome facettaire)', 'genericRelation', 'sous-type'),
#  ('interrogatoire', 'associativeRelation', 'examen clinique'),
#  ('interrogatoire', 'activityRelation', 'sous-groupe'),
#  ('examen clinique', 'activityRelation', 'sous-groupe'),
#  ('méta-analyse', 'activityRelation', 'lombalgies'),
#  ('recommandation', 'originationRelation', 'HAS'),
#  ('HAS', 'activityRelation', 'prise en charge'),
#  ('HAS', 'associativeRelation', 'lombalgie'),
#  ('HAS', 'activityRelation', 'définition'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('prise en charge', 'activityRelation', 'lombalgie'),
#  ('lombalgie', 'propertyRelation', 'chirurgicale'),
#  ('définition', 'activityRelation', 'lombalgie'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('iliaque', 'spatialRelation', 'cuisse'),
#  ('iliaque', 'spatialRelation', 'genou'),
#  ('genou', 'partitiveRelation', 'cuisse'),
#  ('lombalgie chronique', 'genericRelation', 'trouble'),
#  ('lombalgie chronique', 'associativeRelation', 'différenciant'),
#  ('différenciant', 'propertyRelation', 'définition'),
#  ('lombalgie non dégénérative', 'genericRelation', 'lombalgie'),
#  ('lombalgie dégénérative', 'genericRelation', 'lombalgie'),
#  ('lombalgie spécifique', 'genericRelation', 'lombalgie'),
#  ('lombalgie secondaire', 'genericRelation', 'cause; causes'),
#  ('lombalgie secondaire', 'propertyRelation', 'symptomatique)'),
#  ('lombalgie secondaire', 'associativeRelation', 'traumatique; tumorale'),
#  ('symptomatique)', 'associativeRelation', 'traumatique; tumorale'),
#  ('traumatique', 'genericRelation', 'cause; causes'),
#  ('tumorale', 'genericRelation', 'cause; causes'),
#  ('infectieuse ou inflammatoire', 'genericRelation', 'cause; causes'),
#  ('discogénique', 'associativeRelation', 'facettaire'),
#  ('mixte', 'genericRelation', 'discogénique'),
#  ('ligamentaire', 'genericRelation', 'discogénique'),
#  ('musculaire', 'partitiveRelation', 'mixte'),
#  ('musculaire', 'partitiveRelation', 'ligamentaire'),
#  ('régional', 'genericRelation', 'trouble'),
#  ('statique rachidienne', 'propertyRelation', 'trouble'),
#  ('statique rachidienne', 'propertyRelation', 'régional'),
#  ('lombalgie', 'genericRelation', 'cause; causes'),
#  ('lombalgie', 'associativeRelation', 'lésions anatomiques'),
#  ('recommandations', 'associativeRelation', 'lombalgie dégénérative'),
#  ('lombalgie dégénérative', 'propertyRelation', 'discogénique'),
#  ('spondylolisthésis', 'associativeRelation', 'radiculalgie'),
#  ('canal lombaire étroit', 'associativeRelation', 'radiculalgie'),
#  ('lombalgie', 'partitiveRelation', 'spondylolisthésis'),
#  ('lombalgie', 'partitiveRelation', 'canal lombaire étroit'),
#  ('lombalgie', 'associativeRelation', 'radiculalgie'),
#  ('diagnostique', 'associativeRelation', 'recommandations'),
#  ('lombalgie chronique', 'associativeRelation', 'lombalgie'),
#  ('chronique dégénérative',
#   'associativeRelation',
#   'lombalgie non dégénérative'),
#  ('sciatique', 'propertyRelation', 'définition'),
#  ('radiculalgie', 'associativeRelation', 'sciatique'),
#  ('anatomiquement exact', 'associativeRelation', 'cruralgie'),
#  ('recommandations', 'associativeRelation', 'radiculalgie'),
#  ('belges', 'activityRelation', 'radiculalgie'),
#  ('États-Unis', 'genericRelation', 'recommandations'),
#  ('Canada', 'associativeRelation', 'sciatique'),
#  ('NICE britannique', 'partitiveRelation', 'Canada'),
#  ('NICE britannique', 'associativeRelation', 'sciatique'),
#  ('KCE belge', 'activityRelation', 'définition'),
#  ('KCE belge', 'activityRelation', 'radiculalgie'),
#  ('KCE belge', 'activityRelation', 'consensus'),
#  ('définition', 'activityRelation', 'radiculalgie'),
#  ('radiculalgie', 'associativeRelation', 'consensus'),
#  ('données', 'originationRelation', 'méta-analyse'),
#  ('données', 'associativeRelation', 'lombalgie'),
#  ('méta-analyse', 'associativeRelation', 'lombalgie'),
#  ('lombalgie', 'genericRelation', 'douleur; douleurs'),
#  ('récidivante', 'associativeRelation', 'études'),
#  ('récidivante', 'associativeRelation', 'récurrences'),
#  ('récurrences', 'partitiveRelation', 'études'),
#  ('douleur', 'propertyRelation', 'sévérité'),
#  ('douleurs', 'propertyRelation', 'sévérité'),
#  ('revue', 'associativeRelation', 'méta-analyse'),
#  ('littérature', 'associativeRelation', 'méta-analyse'),
#  ('méta-analyse', 'associativeRelation', 'trajectoires de douleur'),
#  ('patients lombalgiques', 'propertyRelation', 'douleurs fluctuantes'),
#  ('patients', 'associativeRelation', 'lombalgiques'),
#  ('recommandations', 'associativeRelation', 'lombalgies chroniques'),
#  ('allemandes', 'genericRelation', 'recommandations'),
#  ('allemandes', 'associativeRelation', 'lombalgies chroniques'),
#  ('lombalgies', 'propertyRelation', 'risque'),
#  ('lombalgies', 'associativeRelation', 'chronicisation'),
#  ('risque', 'associativeRelation', 'chronicisation'),
#  ('recommandations', 'associativeRelation', 'terme'),
#  ('radiculalgie', 'associativeRelation', 'douleur'),
#  ('membres inférieurs', 'associativeRelation', 'dermatomes'),
#  ('lombalgie commune', 'associativeRelation', 'signes'),
#  ('douleur lombaire', 'propertyRelation', 'signes'),
#  ('drapeaux rouges)', 'genericRelation', 'liste'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'termes'),
#  ('patient', 'activityRelation', 'diagnostic'),
#  ('lombalgie commune', 'propertyRelation', 'rassurante'),
#  ('lombalgie commune', 'propertyRelation', 'pronostic'),
#  ('pronostic', 'propertyRelation', 'rassurante'),
#  ('lombalgie chronique', 'associativeRelation', 'lombalgie'),
#  ('Pistes', 'activityRelation', 'définition'),
#  ('Pistes', 'associativeRelation', 'lombalgie commune'),
#  ('définition', 'activityRelation', 'lombalgie commune'),
#  ('lombalgie commune', 'genericRelation', 'lombalgie récidivante; lombalgie'),
#  ('poussée aiguë de lombalgie',
#   'genericRelation',
#   'lombalgie à risque de chronicité'),
#  ('lombalgie aiguë', 'genericRelation', 'lombalgie à risque de chronicité'),
#  ('douleurs aiguës', 'genericRelation', 'traitements'),
#  ('douleur de fond', 'genericRelation', 'douleurs aiguës'),
#  ('intensification temporaire', 'activityRelation', 'traitements'),
#  ('intensification temporaire',
#   'activityRelation',
#   'médicamenteux ou non médicamenteux'),
#  ('intensification temporaire', 'genericRelation', 'termes'),
#  ('temporaire', 'activityRelation', 'traitements'),
#  ('temporaire', 'activityRelation', 'médicamenteux ou non médicamenteux'),
#  ('temporaire', 'genericRelation', 'termes'),
#  ('médicamenteux ou non médicamenteux', 'genericRelation', 'traitements'),
#  ('lombalgie à risque de chronicité',
#   'genericRelation',
#   'lombalgie récidivante; lombalgie'),
#  ('lombalgie à risque de chronicité', 'associativeRelation', 'patients'),
#  ('lombalgie à risque de chronicité',
#   'associativeRelation',
#   'durée d’évolution'),
#  ('patients', 'propertyRelation', 'durée d’évolution'),
#  ('résolution', 'genericRelation', 'capacités fonctionnelles'),
#  ('lombalgie récidivante', 'genericRelation', 'douleur de fond'),
#  ('lombalgie récidivante', 'associativeRelation', 'risque'),
#  ('lombalgie récidivante', 'associativeRelation', 'drapeaux jaunes'),
#  ('lombalgie', 'genericRelation', 'douleur de fond'),
#  ('lombalgie', 'associativeRelation', 'risque'),
#  ('lombalgie', 'associativeRelation', 'drapeaux jaunes'),
#  ('récidive', 'associativeRelation', 'lombalgie récidivante; lombalgie'),
#  ('lombalgie', 'propertyRelation', 'risque'),
#  ('Prise', 'associativeRelation', 'patient'),
#  ('Prise', 'associativeRelation', 'lombalgique'),
#  ('patient', 'associativeRelation', 'lombalgique'),
#  ('patient', 'activityRelation', 'prise en charge'),
#  ('patient', 'activityRelation', 'vécu'),
#  ('patient', 'associativeRelation', 'douleur'),
#  ('retentissement', 'activityRelation', 'douleur'),
#  ('prise en charge globale', 'associativeRelation', 'bio'),
#  ('patient', 'activityRelation', 'termes'),
#  ('patient', 'activityRelation', 'diagnostic'),
#  ('pronostic', 'propertyRelation', 'rassurante'),
#  ('lombalgie commune', 'propertyRelation', 'rassurante'),
#  ('lombalgie commune', 'propertyRelation', 'pronostic'),
#  ('lombalgie', 'propertyRelation', 'risque'),
#  ('lombalgie', 'associativeRelation', 'chronicité'),
#  ('lombalgie', 'associativeRelation', 'chronique'),
#  ('lombalgie', 'associativeRelation', 'prise'),
#  ('risque', 'associativeRelation', 'chronicité'),
#  ('risque', 'associativeRelation', 'chronique'),
#  ('chronicité', 'associativeRelation', 'chronique'),
#  ('chronicité', 'associativeRelation', 'prise'),
#  ('chronique', 'associativeRelation', 'prise'),
#  ('prise', 'activityRelation', 'risque'),
#  ('en charge pluridisciplinaire', 'associativeRelation', 'kinésithérapeute'),
#  ('rhumatologue', 'genericRelation', 'kinésithérapeute'),
#  ('médecine physique et de réadaptation', 'genericRelation', 'spécialiste'),
#  ('médecine physique et de réadaptation',
#   'associativeRelation',
#   'médecin du travail'),
#  ('médecin du travail', 'genericRelation', 'spécialiste'),
#  ('patient', 'associativeRelation', 'situation'),
#  ('patient', 'associativeRelation', 'préférences'),
#  ('patient', 'associativeRelation', 'ressources'),
#  ('préférences', 'associativeRelation', 'ressources'),
#  ('système', 'propertyRelation', 'localement'),
#  ('délétère', 'associativeRelation', 'discours discordants'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('Évaluation clinique', 'instrumentalRelation', 'recherche'),
#  ('Évaluation clinique', 'activityRelation', 'drapeaux rouges'),
#  ('douleur lombaire', 'associativeRelation', 'drapeaux rouges'),
#  ('recherche', 'activityRelation', 'drapeaux rouges'),
#  ('Synthèse', 'activityRelation', 'recommandations'),
#  ('Synthèse', 'activityRelation', 'lombalgie'),
#  ('drapeaux rouges', 'propertyRelation', 'Synthèse'),
#  ('drapeaux rouges', 'partitiveRelation', 'recommandations'),
#  ('drapeaux rouges', 'partitiveRelation', 'lombalgie'),
#  ('Promoteur', 'associativeRelation', 'Année'),
#  ('Promoteur', 'associativeRelation', 'Pays'),
#  ('Année', 'associativeRelation', 'Pays'),
#  ('diagnostics différentiels', 'activityRelation', 'douleur'),
#  ('patient', 'propertyRelation', 'douleur'),
#  ('lombaire', 'associativeRelation', 'symptômes'),
#  ('radiculaire', 'associativeRelation', 'symptômes'),
#  ('symptômes', 'propertyRelation', 'existants'),
#  ('signes', 'associativeRelation', 'pathologie'),
#  ('pathologie', 'propertyRelation', 'grave'),
#  ('grave', 'genericRelation', 'signes'),
#  ('rouges', 'associativeRelation', 'cancer'),
#  ('rouges', 'associativeRelation', 'infection'),
#  ('rouges', 'associativeRelation', 'traumatisme'),
#  ('rouges', 'associativeRelation', 'maladie inflammatoire'),
#  ('rouges', 'associativeRelation', 'spondylarthrite'),
#  ('traumatisme', 'genericRelation', 'infection'),
#  ('maladie inflammatoire', 'genericRelation', 'infection'),
#  ('spondylarthrite', 'genericRelation', 'infection'),
#  ('syndrome de la queue de cheval',
#   'genericRelation',
#   'problème neurologique'),
#  ('recommandation', 'propertyRelation', 'Niveau'),
#  ('opinion d’experts', 'genericRelation', 'Niveau'),
#  ('Niveau de preuve', 'associativeRelation', 'objet'),
#  ('drapeaux rouges', 'propertyRelation', 'groupes'),
#  ('drapeaux rouges', 'propertyRelation', 'spécificité'),
#  ('drapeaux rouges', 'propertyRelation', 'combinaison'),
#  ('conduite à tenir', 'genericRelation', 'guidelines'),
#  ('Centre fédéral d’expertise', 'genericRelation', 'groupes'),
#  ('Centre fédéral d’expertise',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('HAS', 'genericRelation', 'groupes'),
#  ('HAS',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('National Institute for Les drapeaux rouges', 'genericRelation', 'groupes'),
#  ('National Institute for Les drapeaux rouges',
#   'associativeRelation',
#   'Service des bonnes pratiques professionnelles'),
#  ('Belgique', 'genericRelation', 'Pays'),
#  ('patient', 'associativeRelation', 'lombalgie commune'),
#  ('patient', 'activityRelation', 'Prise'),
#  ('lombalgie commune', 'genericRelation', 'douleur'),
#  ('Promoteur', 'associativeRelation', 'Année'),
#  ('Promoteur', 'associativeRelation', 'Pays'),
#  ('Année', 'genericRelation', 'douleur'),
#  ('Année', 'associativeRelation', 'Pays'),
#  ('Semi-urgent', 'genericRelation', 'Urgent'),
#  ('Prise', 'activityRelation', 'lombalgie commune'),
#  ('combinaison', 'propertyRelation', 'spécificité'),
#  ('suspecter', 'activityRelation', 'pathologie grave'),
#  ('suspecter', 'associativeRelation', 'douleur'),
#  ('pathologie grave', 'associativeRelation', 'douleur'),
#  ('Health and Care', 'genericRelation', 'guide'),
#  ('Health and Care', 'associativeRelation', 'NICE'),
#  ('Health and Care', 'associativeRelation', 'généralistes'),
#  ('guide', 'originationRelation', 'NICE'),
#  ('guide', 'instrumentalRelation', 'adressage approprié'),
#  ('guide', 'associativeRelation', 'généralistes'),
#  ('guide', 'associativeRelation', 'services spécialisés)'),
#  ('NICE', 'activityRelation', 'adressage approprié'),
#  ('NICE', 'associativeRelation', 'généralistes'),
#  ('NICE', 'associativeRelation', 'services spécialisés)'),
#  ('adressage approprié', 'activityRelation', 'services spécialisés)'),
#  ('généralistes', 'activityRelation', 'adressage approprié'),
#  ('généralistes', 'associativeRelation', 'services spécialisés)'),
#  ('services spécialisés)', 'partitiveRelation', 'Health and Care'),
#  ('Excellence', 'associativeRelation', 'degré'),
#  ('signes neurologiques',
#   'associativeRelation',
#   'syndrome de la queue de cheval'),
#  ('syndrome de la queue de cheval', 'associativeRelation', 'déficit moteur'),
#  ('syndrome de la queue de cheval', 'associativeRelation', 'anesthésie péri'),
#  ('déficit moteur', 'genericRelation', 'signes neurologiques'),
#  ('déficit moteur', 'associativeRelation', 'anesthésie péri'),
#  ...]

# %%
len(relations)
# Out:
# 1590

# %% [markdown]
# ## Extracting terms

# %%
terms = []
for entity in dictRest:
    terms.append(entity[2]['term'])

# %%
terms
# Out:
# ['lombalgie',
#  'arrêt de travail',
#  'arrêts de travail',
#  'accidents du travail',
#  'cause',
#  'motif',
#  'chronicisation',
#  'lombalgie',
#  'douleur lombaire',
#  'douleur radiculaire',
#  'guide',
#  'douleur radiculaire',
#  'douleur',
#  'extrémités inférieures',
#  'dermatome(s)',
#  'patients',
#  'lombalgie',
#  'isolée',
#  'douleurs radiculaires',
#  'douleur provoquée',
#  'composante',
#  'neuropathique',
#  'lésion du système nerveux)',
#  'douleurs lombaires',
#  'lombalgie)',
#  'douleurs lombaires et radiculaires',
#  'sciatique)',
#  'version française']

# %%
len(terms)
# Out:
# 28

# %%
len(set(terms))
# Out:
# 25

# %%
import pandas as pd

df = pd.DataFrame(relations, columns = ["term 1", "relation", "term 2"])

df.to_excel("text2TCS_triples.xlsx")

# %%
with open("Text2TCS_triples.json", 'w', encoding="UTF-8") as f:
    f.write(json.dumps(relations))

# %%
with open("Text2TCS_terms.json") as f:
    terms = json.loads(f.read())
