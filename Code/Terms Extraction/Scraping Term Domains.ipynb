# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url="https://vitrinelinguistique.oqlf.gouv.qc.ca/resultats-de-recherche?tx_solr%5Bfilter%5D%5B0%5D=type_stringM%3Abdl&tx_solr%5Bfilter%5D%5B1%5D=type_stringM%3Agdt&tx_solr%5Bq%5D=l%C3%A9sion"
response = requests.get(url)

# %%
from urllib.parse import unquote

url_encoded = unquote(url)
url_encoded
# Out:
# 'https://vitrinelinguistique.oqlf.gouv.qc.ca/resultats-de-recherche?tx_solr[filter][0]=type_stringM:bdl&tx_solr[filter][1]=type_stringM:gdt&tx_solr[q]=lésion'

# %%
# It does the same thing like the previous function
# requests.utils.unquote(url)
# Out:
# 'https://vitrinelinguistique.oqlf.gouv.qc.ca/resultats-de-recherche?tx_solr[q]=lésion&tx_solr[filter][0]=type_stringM:bdl&tx_solr[filter][1]=type_stringM:gdt'

# %%
html = response.content

# %%
soup = bs(html, "lxml")

# %%
soup.title
# Out:
# <title>Résultats de recherche</title>

# %%
soup.title.getText()
# Out:
# 'Résultats de recherche'

# %% [markdown]
# ## Getting the number of definitions finded

# %%
number_str = soup.find("div", class_ = "search-results__count").get_text()

# %%
number_str
# Out:
# '\n1715 résultat(s)\n'

# %%
import re

numOfDomains = int(re.findall(r'\d+', number_str)[0])

numOfDomains
# Out:
# 1715

# %% [markdown]
# ## Getting the list of domains

# %%
domaines_def = soup.find_all("p", class_="result__domaines")

# %%
domains_name = []
for domaine in domaines_def:
    domains_name.append(domaine.get_text(strip=True))

# %%
import pandas as pd

domains_series = pd.Series(domains_name)
domains_series.value_counts()
# Out:
# médecine                            15
# droit                                3
# assurance                            2
# assurance|sécurité                   2
# botanique                            1
# appellation de personne|médecine     1
# assurance|travail                    1
# dtype: int64

# %% [markdown]
# ## Applying this method to all Terms

# %%
import json
with open('allTerms.json') as f:
    allTerms = json.loads(f.read())

# %%
allTerms
# Out:
# ['qg',
#  'williams ka',
#  'meta manipulative treatment',
#  'actif',
#  'alves nogueira d',
#  'colonne',
#  'manipulation de la colonne vertbrale',
#  'ieee',
#  'marche',
#  'facet joint syndrome',
#  'composante physique',
#  'shearer hm',
#  'suspicion',
#  'prevalence',
#  'stimulation',
#  'exact',
#  'liste',
#  'ribeiro',
#  'traitements anticonvulsivants',
#  'patient des effets indsirables',
#  'autorit de sant',
#  'ulcre perfor',
#  'fonctionnelles',
#  'prreprise',
#  'multimodale',
#  'examen clinique du rachis',
#  'tomography',
#  'liste est non exhaustive',
#  'orthopaedic',
#  'lyon',
#  'sanitarias',
#  'protocole de la cochrane',
#  'imagerie rachidienne',
#  'enceintes',
#  'curative',
#  'interquartile',
#  'Web',
#  'mcanismes',
#  'critre principal radiofrquence pulse',
#  'ngatives',
#  'corticodes par voie pidurale',
#  'incluses',
#  'ha',
#  'poinsignon',
#  'kennedy n',
#  'activit normale',
#  'opiodes forts',
#  'r0320434htm',
#  'almeida',
#  'institut national de veille',
#  'vise myorelaxante',
#  'mouvements actifs spcifiques',
#  'irritation des racines lombo',
#  'formulation de conclusion ou de recommandation',
#  'technique de dernier recours',
#  'herniated lumbar disk',
#  'tassoni',
#  'inhibiteur',
#  'infection vih',
#  'grande',
#  'jessica layouni',
#  'dfinition dune lombalgie',
#  'preuss',
#  'vidence conflictuelle',
#  'questions',
#  'and care excellence',
#  'no',
#  'patient  risque de chronicit',
#  'rassurante',
#  'adaptation',
#  'center bibliothque mdicale lemanissier canadian agency',
#  'invasifs',
#  'chef de projet',
#  'paramdicaux',
#  'recours  la stimulation',
#  'socit franaise de mdecine physique',
#  'pelvi fmoral',
#  'pilates',
#  'comptence mdecine manuelle',
#  'prise en compte',
#  'tractions manuelles',
#  'problmatiques',
#  'bnficier',
#  'participants',
#  'systme de sant',
#  'mta',
#  'degr',
#  'rducateur',
#  'discordants',
#  'techniques manuelles passives',
#  'racines',
#  'minimales',
#  'sbpp',
#  'pratiques',
#  'retrainpainorg',
#  'promotion de la marche',
#  'sfmg',
#  'google',
#  'infrieurs',
#  'vraie',
#  'infiltrations pidurales de of science',
#  'adalimumab',
#  'belief questionnaire',
#  'vraiment',
#  'xq',
#  'national institute',
#  'prescriptions',
#  'slection des recherche',
#  'sanitaire',
#  'change pain latin',
#  'qualit moyenne',
#  'franke jd',
#  'ls',
#  'ostopathes',
#  'wieland ls',
#  'canal lombaire',
#  'pluridisciplinarit',
#  'usagers',
#  'int orthop 2016',
#  'ostoarticulaires',
#  'jeux de ballon',
#  'future',
#  'avantages potentiels',
#  'coles du dos qualitative',
#  'mcgill',
#  'favorable',
#  'wambeke',
#  'thabane',
#  'early',
#  'ferreira ph',
#  'service m dical',
#  'change pain',
#  'charge physique leve',
#  'actaminophne',
#  'guide mthodologique de la has',
#  'relaxant',
#  'maladie chronique',
#  'douleurs myofasciales',
#  'exercices directionnels',
#  'absentisme au travail',
#  'pathologie rachidienne en lien',
#  'wang s',
#  'jambe',
#  'tulder exercise',
#  'rx',
#  'non randomises',
#  'college of',
#  'heritage foundation',
#  'pied',
#  'peuton',
#  'considered',
#  'new zealand',
#  'lornoxicam non disponible',
#  'trauma',
#  'ojha ha',
#  'groeneweg jg',
#  'rachialgie chronique',
#  'transversales',
#  'srbely j',
#  'caudales',
#  'entranement fonctionnel',
#  'gellhorn',
#  'greenhalgh',
#  'salud',
#  'an american',
#  'diagnostic diffrentiel',
#  'recommandations spcifiques',
#  'non chirurgicale',
#  'intrts',
#  'back review',
#  'titre champs et objectifs',
#  'ordre',
#  'maher cg',
#  'thrapies passives isoles',
#  'liaw lj',
#  'raison',
#  'spcialiste',
#  'feedback respiratoire',
#  'l5s1',
#  'rapport de 146 pages',
#  'hydrocortancyl4',
#  'histoire naturelle',
#  'premier recours',
#  'chronic',
#  'Rapid Response Reportreference list',
#  'pathologie sousjacente',
#  'neurophysiological pain education',
#  'question critres de slection',
#  'synthtique',
#  'semelles orthopdiques',
#  'fort',
#  'yh',
#  'rsolution',
#  'points',
#  'acupressure',
#  'protocol for traffic injury management',
#  'ruddock jk',
#  'clinical management',
#  'non curative',
#  'risk assessment tool',
#  'troubles sensoriels',
#  'amliorations de la douleur',
#  'odds',
#  'van eerd',
#  'importance',
#  'rle',
#  'commission de la transparence5',
#  'couban',
#  'harpagophytum procumbens',
#  'ghiselli',
#  'activation synergique',
#  'radiculalgie',
#  'lombalgie d  origine professionnelle',
#  'pratique clinique',
#  'ty',
#  'angers',
#  'voie foraminale wei',
#  'preuve tait trs basse',
#  'researchgate',
#  'guise',
#  'algorithme canadien',
#  'scielo',
#  'lancet sur le paractamol',
#  'cervicales',
#  'cupping groupe contrle',
#  'agree',
#  'pleurale',
#  'stabilisation taient plus efficaces',
#  'tulder',
#  'irm cinahl',
#  'ageing',
#  'spinales',
#  'recherche dans la base',
#  'mdicaments antispastique',
#  'pain latin america advisory panel',
#  'cadres',
#  'ventuellement',
#  'chiropr',
#  'adoption par le collge',
#  'endroits',
#  'kcefgovbe',
#  'psychologie de la sant',
#  'intensification temporaire des traitements',
#  'institute for clinical',
#  'activits physiques',
#  'computed',
#  'kinsithrapie',
#  'treating',
#  'obstacle',
#  'tecnologas sanitarias',
#  'registre cochrane des lombalgie',
#  'chughtai',
#  'percutans discaux',
#  'critre de slection',
#  'praticiensachant',
#  'saule rouge',
#  'risque lombaire',
#  'neurophysiologiedouleur',
#  'revue de la littrature',
#  'tamment',
#  'shaw',
#  'ontario health technology',
#  'acupuncture de subaigu',
#  'annales de radaptation et de mdecine',
#  'imagerie en coupes',
#  'tests',
#  'infection',
#  'biblio canada',
#  'effets escondaires mineurs',
#  'systmes de stabilisation dynamique',
#  'radiographies',
#  'anheyer',
#  'dformation structurale importante de la colonne',
#  'j pharmacother',
#  'double cochrane des essais',
#  'seules',
#  'james',
#  'activits sportives tableau 40',
#  'direct access',
#  'psychologiques',
#  'groupes',
#  'dr rogatien',
#  'muscles transverse',
#  'radiographies de la colonne lombaire',
#  'international network of agencies',
#  'svp',
#  'opioides',
#  'cliniques',
#  'rheum',
#  'r43215',
#  'recommandations du department',
#  'chronique',
#  'douleurs  la jambe ou  la fesse',
#  'facettaire',
#  'signification rfrence',
#  'limite chronique',
#  'grandes',
#  'diofrquence',
#  'profession',
#  'paragraphe',
#  'version courte',
#  'mtaanalyse de la ligne cidessus',
#  'algorithmes lombalgie',
#  'revues',
#  'back belief questionnaire',
#  'lombalgie contrls',
#  'qualit faible',
#  'backpaintreatment',
#  'dure',
#  'cognitivocomportemental',
#  'maladie sfcr',
#  'mdicoconomique',
#  'pain latin america',
#  'urman',
#  'GRADE working group',
#  'department of',
#  'recommandations nordamricaines',
#  'issu',
#  'groupe pedro',
#  'college of chargesproduits17',
#  'analgsiques',
#  'contextes',
#  'coping',
#  'ansm',
#  'spinal manipulation',
#  'primaires',
#  'dr michle',
#  'rducative tableau',
#  'mdecins ostopathes',
#  'statique',
#  'sophistiqu',
#  'burton ak',
#  'Collge de la Haute Autorit de Sant',
#  'inhibiteurs de recapture de la srotonine',
#  'charges concomitantes',
#  'college',
#  'stagnation',
#  'chiropr med',
#  'jourdan',
#  'simic m',
#  'signe dalerte',
#  'grabherr',
#  'pressman',
#  'conseil national professionnel de mdecine',
#  'programmes de contrle du mouvement',
#  'borghi',
#  'drapeaux rouges physiques',
#  'compltes',
#  'chronique grave',
#  'gao h',
#  'thrapie toward optimized practice',
#  'formations',
#  'spcifique',
#  'herbert',
#  'lanhers',
#  'bilan',
#  'maladie pour lombalgie',
#  'comportement',
#  'mdecins de la douleur',
#  'strenger',
#  'fiche de synthse',
#  'charge antalgique',
#  'pinheiro cochrane',
#  'transparence',
#  'coute',
#  'ferreira m',
#  'haute',
#  'most red',
#  'rubriques',
#  'NP Grading Oui',
#  'rsolutive',
#  'gellhorn ac',
#  'ensuite',
#  'respectif',
#  'exercices graduel',
#  'camacho',
#  'koes',
#  'erp rm',
#  'pain',
#  'cidessous',
#  'phase aigu',
#  'educ couns',
#  'medical research',
#  'subaigu',
#  'pathologie sousjacente  la douleur lombaire',
#  'imageries',
#  'hospitaliss',
#  'lombalgie chronique de destravailleurs',
#  'telehealth',
#  'claudication',
#  'associations',
#  'acti',
#  'limite contrle radiologique',
#  'stratification du risque de passage',
#  'yu l',
#  'group',
#  'jj',
#  'clearinghouse agency for healthcare research',
#  'kendall',
#  'toward',
#  'descripteurs',
#  'lumbago',
#  'valuation des biais',
#  'serious',
#  'guide',
#  'sandrine',
#  'branche mdiale',
#  'urman rd',
#  'stimulation mdullaire',
#  'croyance',
#  'significatif',
#  'douleur incapacitante',
#  'exercices de contrle du mouvement',
#  'wilhelm m',
#  'jia',
#  'j pain',
#  'dfinitions',
#  'gross dp',
#  'chirurgien',
#  'denervation',
#  'lutte antirhumastismale',
#  'selfe',
#  'fractionne',
#  'lments',
#  'camacho lopez pa',
#  'ribeiro da silva m',
#  'faux cupping',
#  'ge avanc',
#  'pdagogiques',
#  'pidurales',
#  'cause traumatique',
#  'association australian government',
#  'vorobeychik',
#  'attentes',
#  'dotta l',
#  'diagnostic postural',
#  'cohrence diagnostic',
#  'burton k 2009',
#  'american society of patients',
#  'pistes de rflexion',
#  'incluant',
#  'Collge de la HAS',
#  'ktoprofne',
#  'greenhalgh s1',
#  'synthtiques',
#  'congrs de kinsithrapie',
#  'annals',
#  'network',
#  'inter pineux modifications',
#  'veterans affairs',
#  'charge non mdicamenteuse',
#  'vie qualit de vie',
#  'lombalgie chronique',
#  'injection pidurale',
#  'mixte',
#  'ribeiro da silva',
#  'quality',
#  'clinic',
#  'serious pathology of',
#  'secondaire',
#  'neck',
#  'sectaire',
#  'pinto r',
#  'heymans',
#  'activits de la vie quotidienne',
#  'stimulation de haute frquence',
#  'year in relaxants',
#  'chen j',
#  'charge biopsychosociale',
#  'meagher',
#  'dc',
#  'troubles statiques',
#  'diagnostic principal',
#  'quality measures',
#  'tableau clinique',
#  'radiographie du rachis lombaire',
#  'hutchison ca',
#  'clairement',
#  'outils',
#  'cochrane pooles',
#  'demie',
#  'charg de projet',
#  'method of mechanical diagnosis and therapy',
#  'cliniquement',
#  'meloxicam',
#  'socit franaise d  ostopathie sfr',
#  'pousse aigu de lombalgie',
#  'radaptation active',
#  'physiques',
#  'programme de radaptation active plus vaste',
#  'dpenses de sant',
#  'harned me',
#  'patch de lidocane',
#  'enjeu conomique',
#  'infiltratif',
#  'ambiguit',
#  'analyse mdicale',
#  'fiches pertinences',
#  'ngligeables',
#  'infiltration articulaire',
#  'conservative treatments',
#  'recommandation forte',
#  'danemark pour lombalgie',
#  'knowledge',
#  'tude observationnelle',
#  'mtier',
#  'caudale',
#  'dates limites',
#  'efficacit sur la douleur',
#  'cochrane superficiel',
#  'psychinfo',
#  'health new zealand',
#  'insuffisantes',
#  'ultrasoundguided versus fluoroscopy',
#  'arflxie',
#  'protocole thrapeutique',
#  'lisi',
#  'section of',
#  'sousgroupes',
#  'fnmr',
#  'exercices de kinsithrapie',
#  'partenariat',
#  'atteinte cardiaque',
#  'maladie musculosquelettique et rhumatismale',
#  'compensation',
#  'traitements percutans',
#  'sites',
#  'anesthsie pri',
#  'mthode de travail',
#  'france',
#  'complexe lombo pelvi fmoral',
#  'transparence du 9 novembre',
#  'decina',
#  'millions',
#  'lombosciatique rhumatologie',
#  'pourpre',
#  'uk',
#  'jr',
#  'mdecins de',
#  'beek',
#  'cg',
#  'chronic spinal',
#  'freitas sr',
#  'fonction',
#  'qualit articles',
#  'pathologie srieuse',
#  'education de la sant',
#  'amaigrissement',
#  'kinsithrapeutiques',
#  'corticothrap',
#  'college of 2017',
#  'cinq tudes',
#  'mclachlan',
#  'muscle',
#  'douleur medline',
#  'sciverse',
#  'morphiniques',
#  'cssia lopes',
#  'davenport',
#  'biopsycho',
#  'integrative',
#  'heymans mw',
#  'cancreuse',
#  'ADAPTE',
#  'professions',
#  'unit d  valuation',
#  'critres de slection recherche',
#  'contreras lopez',
#  'activit professionnelle',
#  'qubec cochrane library database centre',
#  'poppel mnm',
#  'niveau de preuve',
#  'systemic corticosteroids',
#  'behav',
#  'MEDLINE',
#  'hurley',
#  'rentranement',
#  'lombosciatique discale tologie',
#  'fonction foraminales',
#  'vcu',
#  'science',
#  'glombiewski ja',
#  'ae de travail',
#  'morphinique',
#  'supplment',
#  'radiculopathy radiculopathie lombaire',
#  'sens clinique',
#  'dfinition claire',
#  'jellema',
#  'f',
#  'stimulation contrls',
#  'an updated',
#  'termes mdicaux et techniques',
#  'clinical recommandations',
#  'tatsunis physicians',
#  'dispositifs inter pineux',
#  'douleur lombaire simple',
#  'ltales',
#  'medline',
#  'majeurs',
#  'guidelines international network',
#  'zoubi',
#  'ce',
#  'dition',
#  'firtch',
#  'tassement vertbral',
#  'cmg',
#  'irradiation',
#  'statut',
#  'rapports de cas',
#  'spinal pain',
#  'downie a',
#  'manuvres',
#  'flags',
#  'amm',
#  'appear safe',
#  'underwood',
#  'meta controlled trials',
#  'agency for healthcare',
#  'lgende',
#  'traitement conservateur',
#  'dlai de recours',
#  'activit physique physiques',
#  'rachidiennes complexes',
#  'wang',
#  'soins franais',
#  'principale',
#  'xu g',
#  'ahrq',
#  'seul est suffisant',
#  'cochrane library',
#  'attitudes',
#  'approche psychologique de type cognitivocomportemental',
#  'mandation',
#  'indiqus',
#  'outils de stratification',
#  'notre temps',
#  'analyse radiographique',
#  'syndrome douleur',
#  'cmk simple',
#  'berquin a',
#  'axen',
#  'composante mentale',
#  'bilan de sant',
#  'option',
#  'infiltrations rachidiennes',
#  'rfrentiel',
#  'branche anesthsique',
#  'spine journal',
#  'centre fdral d  expertise',
#  'comportemental',
#  'nelson nl',
#  'union des masseurs kinsithrapeutes',
#  'colonne vertbrale',
#  'limites',
#  'manipulative therapy',
#  'biblio charge',
#  'programme de medline',
#  'qualit',
#  'groupe paractamol',
#  'opr',
#  'tecnologa',
#  'berman',
#  'top sant',
#  'andersen',
#  'vargas md',
#  'lobjetcif de la fiche',
#  'access',
#  'schrder',
#  'lomboradiculalgie chronique',
#  'jacobson',
#  'patient lombalgique',
#  'Accord dexperts',
#  'douleur',
#  'recherche biblio pour les patients',
#  'rcidive',
#  'tudes de cohortes valuation des medline',
#  'adopt',
#  'chauffer',
#  'stevens ml',
#  'care',
#  'vitements',
#  'intervention',
#  'lombalgies lombaires',
#  'opinion dexperts',
#  'relaxants',
#  'TOP',
#  'mckenzie',
#  'mta rgression',
#  'spondylodiscite',
#  'avoidance belief',
#  'douleur aigu svre',
#  'chinoises',
#  'inflammation',
#  'california',
#  'objetcif',
#  'ressources du systme de soins disponibles',
#  'chronic systematic reviews',
#  'consultation de gnraliste',
#  'valuation du risque de chronicit',
#  'voire',
#  'exercice en groupe',
#  'direction gnrale',
#  'revue systmatique d  hilton',
#  'approche',
#  'reprsentations',
#  'biais mthodologiques',
#  'fiche synthtique',
#  'impression placebo',
#  'charge kinsithrapique',
#  'radiologue',
#  'mthode d  laboration',
#  'r',
#  'unique',
#  'is vitamin',
#  'prise en charge kinsithrapique',
#  'agency for drugs',
#  'internationale',
#  'mme jessica layouni',
#  'mtaanalyse',
#  'goldgrub',
#  'wood l',
#  'invasive',
#  'drapeaux rouges multiples',
#  'techniques manuelles',
#  'titre prise',
#  'royaumeuni sans radiculalgie',
#  'musculoskeletal problems',
#  'e3373',
#  'spending',
#  'hodges',
#  'distance',
#  'suggestivit',
#  'loureiro',
#  'inutiles',
#  'julia',
#  'douleur rachidienne chronique',
#  'etanercept',
#  'spinal',
#  'carzon jg',
#  'syndrome douloureux chronique',
#  'critre de jugement',
#  'ostopathe',
#  'score',
#  'technique de rducation',
#  'extravertbrale',
#  'pression temporelle',
#  'zadro jr',
#  'administrations orales',
#  'remerciements',
#  'majoritairement',
#  'elmallah',
#  'knowledge infrastructure',
#  'questce quunedrivesectaire',
#  'trouble postural associ',
#  'NICE britannique',
#  'diminution',
#  'haller h',
#  'internationaux',
#  'membres infrieurs',
#  'cohrence thrapeutique',
#  'aquatiques',
#  'charge du patient',
#  'lombalgiques  risque de chronicit',
#  'ovid',
#  'dexamthasone phosphate sodique sans excipients neurotoxiques',
#  'kleijnen',
#  'spine society',
#  'low back',
#  'australian',
#  'zoubi f',
#  'analyse poquet',
#  'ramos',
#  'lieu de vie',
#  'prvalence de lombalgie',
#  'tulder mw',
#  'ac tivit',
#  'quilibre sagittal',
#  'traitement par radiofrquence',
#  'group servicio de evaluacin de tecnologas',
#  'martnez',
#  'servicio de evaluacin',
#  'pain physicians',
#  'soins mdicaux',
#  'management of nonspecific',
#  'mmos',
#  'douleur svre',
#  'comparaison de tudes randomises',
#  'foraminale',
#  'stratgie complte',
#  'verhagen ap',
#  'pathologie grave sousjacente',
#  'utilisation continue',
#  'moura c',
#  'good',
#  'chauffants',
#  'biblio and care',
#  'effet antalgique',
#  'ozone de l  ozone',
#  'douleurs myofasciales needling',
#  'lpezdeuraldevillanueva',
#  'toulotte',
#  'priodes contrle moteur',
#  'cm',
#  'suspicion clinique',
#  'douleur ra',
#  'lombalgie aigu non kinsithrapeutiques',
#  'non american college',
#  'sofmmoo ras',
#  'rfrence',
#  'recherche medline',
#  'fonction exercices',
#  'bloomington',
#  'oliveira magalhaes',
#  'harden',
#  'nots',
#  'terme de lombalgie',
#  'ngatifs',
#  'incitatifs financiers',
#  'myorelaxants disponibles aux tatsunis',
#  'lombalgie commune critres',
#  'tirements',
#  'exercices arobies',
#  'health balgie',
#  'icl',
#  'non mdicamenteux',
#  'bm',
#  'diffrence de douleur',
#  'mode',
#  'passage  la chronicit',
#  'poor outcome',
#  'classification du risque',
#  'toward optimized practice has',
#  'ck',
#  'effect of',
#  'p8 algorithme',
#  'prescription mdicale systmatique',
#  'rehabilitation',
#  'franke',
#  'framesphp',
#  'revue systmatique en lien',
#  'ailleurs',
#  'moteur',
#  'apprhensions',
#  'mdecins de mdecine physique',
#  'pathologie',
#  'referred',
#  'argument scientifique',
#  'mc kenzie',
#  'facettaires',
#  'dsinsertion professionnelle',
#  'rachidiennes non pidurales',
#  '1er recours',
#  'journal',
#  'articles retenus',
#  'pluri professionnalisme',
#  'singapore ministry of health',
#  'clinicaltrialsorg',
#  'phosphate sodique sans excipients neurotoxiques',
#  'localement',
#  'objectif',
#  'needed',
#  'muscles lombaires',
#  'computed tomography scanning',
#  'saragiotto bt',
#  'lombalgies aigus',
#  'schmas de mouvements',
#  'lomboradiculalgie aige',
#  'hcciissuebriefunrestrictedaccess tophysicaltherapypdf sources sfp ',
#  'physique du sf12',
#  'branches du nerf',
#  'prise en charge du rachis',
#  'radiofrquence groupe contrle',
#  'prcisions',
#  'pens centre fdral',
#  'occup rehab',
#  'Indpen',
#  'tive',
#  'grave',
#  'enthoven wt',
#  'multifides',
#  'delarque a tude de l',
#  'lombalgie commune prambule saisine',
#  'mobilit rachidienne',
#  'blue cross',
#  'practice has',
#  'sandrine bercier',
#  'etatsunis lombalgie aigu',
#  'sw',
#  'lumbar',
#  'lombalgies subaigus',
#  'date de critres de slection',
#  'comparable',
#  'manipulations analyse',
#  'sylvie lascols',
#  'scanner',
#  'lectrodes',
#  'biblio lombaires',
#  'lombalgie commune promoteur',
#  'juhl c neurophysiological pain',
#  'seuls',
#  'viudes',
#  'arrts de travail',
#  'cardon',
#  'incertitudes',
#  'antibiotiques',
#  'chef',
#  'hung wc',
#  'danois',
#  'non aquatiques',
#  'lauche',
#  'programmes de manipulations vertbrales',
#  'danemark',
#  'prises en charge',
#  'mthodologie de mtaanalyse',
#  'ajoutez',
#  'sager',
#  'STarT Back Tool',
#  'rechute prjudiciable',
#  'liu xq',
#  'nerveuse',
#  'atouts',
#  'oliveira pena costa',
#  'effet secondaire',
#  'mechanical lam',
#  'prendre en charge',
#  'douleur  court et long terme',
#  'aggravation des symptomes',
#  'mdecins du mouvement  mk',
#  'timmermans',
#  'ness',
#  'comprehensive',
#  'double bloc',
#  'sofcot',
#  'ravaud',
#  'consultation mdicale',
#  'national institute of health des tatsunis',
#  'fond color',
#  'interdisciplinaire',
#  'recapture de la srotonine',
#  'compression pour lombalgie',
#  'exploration biologique',
#  'p8',
#  'chirurgicales',
#  'lectrode de radiofrquence',
#  'qualit de la preuve',
#  'prise en charge rducative',
#  'autogestion',
#  'ws',
#  'veau',
#  'lumbar mr',
#  'mthodologie recherche sciatique',
#  'joint nonsurgical management',
#  'essentielle',
#  'diagnosis',
#  'svres',
#  'voie d  abord foraminale',
#  'lc',
#  'retour rapide au travail',
#  'journal of',
#  'ressources',
#  'radiculalgie prdominante',
#  'pereira b',
#  'probabilit',
#  'daphnoides',
#  'rvaluer',
#  'prescription dopiodes',
#  'je',
#  'j',
#  'retentissement',
#  'intermdiaire',
#  'clinical practice',
#  'insatisfaction au travail',
#  'causalit',
#  'association des masseurs kinsithrapeutes ostopathes',
#  'fan x',
#  'prise en charge financire',
#  'hernies discales panagopoulos',
#  'ebsco',
#  'canadian agency for drugs and technologies',
#  'scottish intercollegiate guidelines',
#  'yang c',
#  'tudes incluses',
#  'syndrome douloureux lombaire',
#  'easa',
#  'ncessaire',
#  'infiltrations randomiss',
#  'viollet e',
#  'ains non slectifs',
#  'guides de bonne pratique',
#  'traumatisme violent',
#  'acp grading',
#  'cadre',
#  'tecnologas sanitarias de galicia',
#  'questionnaire',
#  'advisory panel',
#  'saintdenis dr sandrine bercier',
#  'risques de biais',
#  'department of veterans affairs',
#  'nerve',
#  ...]

# %%
len(allTerms)
# Out:
# 7625

# %%
def scrap(url, term):
    response = requests.get(url_encoded.replace("lésion", term.replace(" ","+")))
    html = response.content
    soup = bs(html, "lxml")
    domaines_def = soup.find_all("p", class_="result__domaines")
    domains_names = []
    for domaine in domaines_def:
        if domaine.get_text(strip=True).find("|") == -1:
            domains_names.append(domaine.get_text(strip=True))
        else:
            domains_names += domaine.get_text(strip=True).split("|")
        
    return domains_names

# %% [markdown]
# We faced here the problem of Temporary Ip Blocks, our IP addresse get blocked while scrapping.
#
# We used these two sources to try solving this problem:
#
# https://www.scraperapi.com/blog/5-tips-for-web-scraping/
# https://medium.com/swlh/improve-your-web-scraper-with-limited-retry-loops-python-35e21730cbf5

# %%
import time
from random import randrange

medical_exist = []
for i,term in enumerate(allTerms[6000:7000]):
    successful = False
    while not successful: 
        try:
            if any(x in scrap(url_encoded, term) for x in ['médecine', 'pharmacologie', 'biologie', 'entraînement physique', 'psychologie', 'chimie', 'sport']):
                medical_exist.append(term)
            print(i," ", term)
            time.sleep(randrange(10, 25))
            successful = True
        except requests.exceptions.RequestException as e:
            random_sleep_except = randrange(240,360)
            print("I've encountered an error! I'll pause for"+str(random_sleep_except/60) + " minutes and try again \n")
            time.sleep(random_sleep_except)
# Out:
# 0   outcome risk
# 1   multidisciplinaires
# 2   mcauley jh
# 3   ornelas j
# 4   costa t
# 5   maher
# 6   miake
# 7   jt
# 8   bienfaits
# 9   niveau de la re
# 10   cupping 2018
# 11   possibilits
# 12   wong
# 13   charge du patient lombalgique
# 14   analyse de dcision
# 15   weng
# 16   dlai de consultation
# 17   of science
# 18   insidieux
# 19   scientifiques
# 20   promoteur haute
# 21   relle
# 22   douleur radiculaire
# 23   cismef cmainfobase
# 24   layouni
# 25   socio
# 26   sfetd
# 27   sihawong
# 28   spinale
# 29   magazines top
# 30   chronique non moteur
# 31   muoz
# 32   doiton
# 33   interdiction
# 34   sciences
# 35   kallewaard jw
# 36   anesth
# 37   salix
# 38   ozone therapy
# 39   dbut
# 40   musculoskelet sci pract
# 41   contenu
# 42   lger
# 43   impairments
# 44   analgsiques non opiodes
# 45   patients
# 46   retard
# 47   biothrapie
# 48   patiente
# 49   vaste
# 50   cage toward thoracique
# 51   sommaire
# 52   institut national de recherche
# 53   antiinflammatoires
# 54   conventionnelle
# 55   amrique latine
# 56   ralistes
# 57   ncb
# 58   pain detect
# 59   valable
# 60   technologies de sant
# 61   intrt
# 62   traitement cibl
# 63   placebo embase
# 64   type
# 65   investigation of red
# 66   nfopam
# 67   agencia de evaluacin de tecnologa
# 68   national clinical guidelines
# 69   treatment of patients
# 70   web zadro
# 71   rx simple
# 72   royaumeuni strodiens
# 73   stades
# 74   nice britannique
# 75   classification du risque de chronicisation
# 76   lombalgie commune critres de slection
# 77   recommandations
# 78   moment
# 79   continuit
# 80   prise en charge multidisciplinaire
# 81   promoteur
# 82   srum chiropractic literature
# 83   deyo r
# 84   tomography scanning
# 85   pluri
# 86   radiculaires GRADE
# 87   dm
# 88   pathologie grave sousjacente  la douleur
# 89   abstraction
# 90   coggon
# 91   analyse en sousgroupe
# 92   j occup rehab 2009
# 93   root pain
# 94   chographie temps rel
# 95   Chi Qong
# 96   lombosciatalgique
# 97   HandicapSant
# 98   lasgue positif
# 99   radaptation american college
# 100   lien avec le travail
# 101   general
# 102   sl
# 103   iliaque
# 104   cadre lgal belge
# 105   cd012087
# 106   luz jnior ma
# 107   randomiss
# 108   franaises
# 109   lopez
# 110   published
# 111   principe de nogier
# 112   study
# 113   kreiner
# 114   oxymorphone
# 115   mental
# 116   salix purpurea
# 117   srum
# 118   probabilit de rcidive
# 119   pillastrini
# 120   forciea
# 121   exposition medline
# 122   surg technol
# 123   lombalgie infrieure
# 124   couban r
# 125   lsions
# 126   ailliet l
# 127   priphrique
# 128   chose
# 129   galicia
# 130   sant urgent
# 131   fin du traitement
# 132   machado gc
# 133   anesthsiques
# 134   cook
# 135   rapport florian
# 136   solution
# 137   open
# 138   analyse quantitative
# 139   soins de sant
# 140   royal
# 141   infiltrations interlamaires
# 142   confrences
# 143   chronic spinal pain
# 144   intensification temporaire des traitements mdicamenteux
# 145   health has
# 146   guidage chographique
# 147   anvrisme de l  aorte
# 148   musculoskelet sci pract malmivaara a
# 149   rgles de bon usage
# 150   rapide
# 151   structures has
# 152   renvoi vers une production
# 153   tudes de cohortes valuation
# 154   chenot jf
# 155   lack empirical
# 156   couns
# 157   diclofnac
# 158   contrle moteur
# 159   arrt de travail
# 160   refshauge
# 161   niveau dactivit
# 162   degr durgence
# 163   mesh
# 164   atonie
# 165   ostoporose
# 166   essais contrls
# 167   dernier recours
# 168   systemic pourlannee2014php
# 169   julia m
# 170   chianca t cupping
# 171   johnson gr
# 172   surgery
# 173   seule
# 174   excluse
# 175   non interventionnel
# 176   kim ch
# 177   alpha
# 178   diffrence rtrospectives
# 179   enjeu
# 180   transforaminale
# 181   infiltrations
# 182   mdecins spcialistes du mouvement
# 183   AINS
# 184   literie
# 185   prvalence de la lombalgie
# 186   arbre
# 187   algique
# 188   grille d  analyse
# 189   arrt de travail prolong
# 190   deneuville
# 191   tatsunis american
# 192   ob jet
# 193   neves n ozone therapy
# 194   parreira p
# 195   antibiotique
# 196   cognitions
# 197   commune
# 198   produitsdelassurance
# 199   radiofrquence groupe
# 200   pertinents
# 201   leve
# 202   accident du travail
# 203   gastrointestinale
# 204   cognitive
# 205   pluridisciplinarit explicite
# 206   local
# 207   traffic injury management
# 208   consultation
# 209   faiblesse du plancher pelvien
# 210   intradiscales
# 211   topiques
# 212   preuves de faible
# 213   littra
# 214   collge de la haute autorit
# 215   cocktail
# 216   interventionnelles
# 217   changements en gras
# 218   meilleure
# 219   temps rel
# 220   yt
# 221   fabq
# 222   egan we
# 223   toward thoracique
# 224   evaluacin de tecnologa
# 225   licences
# 226   axen i
# 227   intervalle de confiance irm
# 228   consensuelle
# 229   yang lh
# 230   dures courtes
# 231   centers
# 232   interventions mdicales
# 233   absentisme
# 234   tissulaire
# 235   vail
# 236   antitnf par voie iv
# 237   pr frontal
# 238   m mo
# 239   classification de la lombalgie
# 240   valuation psycholo gique
# 241   significativement
# 242   ac
# 243   seuils
# 244   autosurveillance
# 245   feedback
# 246   dr sabrina dadoun
# 247   fiche sfo
# 248   auto rducation
# 249   processus
# 250   mobilisations
# 251   douleur de fond prexistante
# 252   annepriscille trouvin
# 253   avis des parties prenantes
# 254   pays de lasgue positif
# 255   n1
# 256   web of science
# 257   charge active
# 258   cochrane central register douleur
# 259   Prises
# 260   lombalgie commune recommandation anne
# 261   science direct
# 262   rgles
# 263   consult
# 264   mri
# 265   rajarathinam
# 266   thrapie de pleine conscience
# 267   prcoce
# 268   arrts
# 269   musculoskelet sci pract 2018
# 270   court
# 271   mineur
# 272   dnervation par dnervation
# 273   sfo
# 274   efficacit plus importante
# 275   inclus
# 276   bases de donnes bibliographiques automatises
# 277   agency
# 278   soins minimaux
# 279   possibility of
# 280   effectiveness of
# 281   tumeur primitive
# 282   vitamin d
# 283   arthritis
# 284   generateur
# 285   classification
# 286   vsicaux
# 287   clarifications
# 288   h
# 289   koleck
# 290   evaluacin
# 291   abrupt
# 292   thoriques
# 293   alape
# 294   oa
# 295   collaboration database
# 296   lombo pelvi fmoral
# 297   lumbar impairments
# 298   postrieure
# 299   recommandations complmentaires
# 300   imagerie
# 301   cortex pr frontal objectiv
# 302   avis
# 303   corsets
# 304   chiropraxie aftnm
# 305   dpistage
# 306   ecodex
# 307   jugement principal
# 308   neuf
# 309   preuve datteinte nerveuse bilatrale
# 310   prise en charge mdicamenteuse
# 311   jl
# 312   troubles fonctionnels
# 313   method of mechanical diagnosis
# 314   colonne lombaire
# 315   social
# 316   grader
# 317   jacente
# 318   habituels
# 319   soins eva
# 320   fractures
# 321   signifiet
# 322   conclusions
# 323   musculoskeletal practice guideline
# 324   ostelo
# 325   prcise
# 326   douleurs cervicales
# 327   phosphate sodique
# 328   diagnostique kinsithrapique
# 329   basocellulaire
# 330   gnraux
# 331   md
# 332   questionnaire rebro
# 333   jg
# 334   analysis
# 335   soins radiculalgie
# 336   kinsithrapie imageries rachidiennes
# 337   radiculaires
# 338   hf
# 339   biopsychosocial
# 340   k
# 341   delarque
# 342   thrapie cognitivo comportementale de la douleur
# 343   wilt
# 344   malmivaara
# 345   technique de rfrence
# 346   central
# 347   movement control exercices
# 348   jones
# 349   liang
# 350   cardoso
# 351   recommandations de bonne pratique
# 352   preuve
# 353   antidpresseurs inhibiteurs de recapture
# 354   mcanisme
# 355   simple backache
# 356   problme des semelles
# 357   algorythme de prise en charge
# 358   actuellement
# 359   lo
# 360   essai randomis contrl
# 361   aggravation progressive
# 362   clinicien
# 363   angulo
# 364   caisse centrale de la mutualit
# 365   ultrasons
# 366   quadriceps
# 367   essais comparatifs
# 368   lobjectif de la fiche
# 369   duval
# 370   aige de lombalgie
# 371   traumatismes graves
# 372   galicia agency for healthcare research
# 373   affection
# 374   web of ruddock
# 375   injections pidurales
# 376   opiodes
# 377   physiologiques
# 378   lombalgie aigu ou subaigu
# 379   prise en charge biopsychosociale
# 380   relaxation progressive
# 381   galtier b
# 382   medicine
# 383   xia c
# 384   KCE
# 385   p
# 386   traitement  vise neuropathique
# 387   tableaux
# 388   dimensions physique
# 389   american college of lombalgie aigu
# 390   rahuma m
# 391   van tulder exercise
# 392   hush j
# 393   classe
# 394   infiltration pidurale
# 395   atteinte pulmonaire ou pleurale
# 396   interrogatoire
# 397   urgences
# 398   partial
# 399   problmes familiaux
# 400   geste invasif
# 401   prvention secondaire
# 402   pilotage du projet
# 403   oprant
# 404   exacerbation
# 405   radiographique
# 406   mdicales
# 407   ajout
# 408   jeanfranois renard
# 409   cortex
# 410   henschke
# 411   compression
# 412   systme de calcul
# 413   patients lombalgiques
# 414   sontils
# 415   tennis
# 416   anti randomized clinical trial
# 417   prsomption
# 418   errones
# 419   pousse aige de lombalgie
# 420   yoga treatment
# 421   conduite thrapeutique
# 422   tlchargeables
# 423   non pidurales
# 424   cumming
# 425   ro
# 426   contraintes
# 427   donnes issues
# 428   tractions lombaires
# 429   zhou
# 430   gabbar oa
# 431   conclusion
# 432   strodiens par voie orale
# 433   bloc articulaire cochrane
# 434   coles du dos pour la lombalgie
# 435   oliveira cb
# 436   incapacit  court has
# 437   incapacit
# 438   rw
# 439   fluoroscopy
# 440   voie antrieure
# 441   london
# 442   critre
# 443   queue de cheval
# 444   care excellence
# 445   intervalles
# 446   care management
# 447   syndrome de la queue
# 448   osullivan
# 449   general practitioners
# 450   obstacles psychosociaux
# 451   lat am enfermagem
# 452   needling
# 453   efficaces
# 454   issue
# 455   roelofs pddm
# 456   conneely
# 457   dcembre
# 458   castro moura c
# 459   instabilit rachidienne
# 460   idem
# 461   arobique
# 462   amricains
# 463   hamilton
# 464   hansen
# 465   syndrome facettaire branche
# 466   critres de jugement court terme
# 467   back pain
# 468   mdecin du travail
# 469   web ducation mdicale
# 470   mondial de la sant
# 471   structurs
# 472   electrical nerve
# 473   centre fdral dexpertise
# 474   force de la recommandation
# 475   chelle pedro
# 476   atteinte
# 477   parcours de soin
# 478   eifel
# 479   pathologies spinales srieuses
# 480   coulombe
# 481   ru
# 482   recherche limite chronique
# 483   poste has
# 484   toward optimized
# 485   nonsurgical treatment
# 486   graduel
# 487   techniciens du sport
# 488   niveau de la recommandation
# 489   textes
# 490   musculoskelet metaanalysis
# 491   analgesics
# 492   nucci
# 493   pena
# 494   tableaux 2122
# 495   preuve tait trs faible
# 496   isolement
# 497   microdiscectomie
# 498   imageries rachidiennes
# 499   bloc dia gnostique de la branche
# 500   technique de gestion des rachidiennes
# 501   signe has
# 502   rappelbonusageains130821pdf
# 503   lobel
# 504   symptmes lombaires
# 505   compatibles
# 506   west midlands
# 507   validation
# 508   fonctionnels
# 509   metaanalysis of
# 510   crdibilit initiale
# 511   lombalgie dgnrative
# 512   syndrome medline
# 513   collaboration database physique
# 514   isrn
# 515   comparatifs
# 516   termes du diagnostic
# 517   electrical nerve stimulation
# 518   croyances
# 519   orthopdiques
# 520   masseurskinsithrapeutes
# 521   van erp
# 522   crans
# 523   lombalgique chronique
# 524   traffic injury
# 525   tractions
# 526   ipaq
# 527   j occup rehab
# 528   symptme neurologique
# 529   pharmacologiques
# 530   valuation des medline
# 531   facilement
# 532   meta controlled
# 533   risques de msusage
# 534   lumbar belt
# 535   with low
# 536   arg
# 537   surveil
# 538   fracture
# 539   educational grant
# 540   exercices de stabilisation
# 541   anti exercise
# 542   objectifs de la fiche
# 543   harpagophytum
# 544   supriorit lecture
# 545   coussins toward
# 546   charge biopsycho sociale
# 547   articles rsultats
# 548   longterm
# 549   rduction des cots
# 550   mriterait
# 551   royaume
# 552   sabrina
# 553   nataires
# 554   prambule
# 555   handicap
# 556   eur spine j
# 557   recommandation
# 558   wilhelm
# 559   transparence5
# 560   donne
# 561   osteba
# 562   union des masseurs kinsithrapeutes ostopathes
# 563   diculaire
# 564   huijnen ip
# 565   symptmes cliniques initiaux
# 566   professionnels de sant
# 567   item
# 568   windt
# 569   pags
# 570   massage
# 571   rgion lombaire
# 572   myorelaxant
# 573   location
# 574   traitements percutans discaux
# 575   biblio physicians
# 576   proton
# 577   rebro short chenot et al
# 578   jaunes bleus
# 579   sharma ml
# 580   2ime
# 581   wei z
# 582   traitement mdicamenteux
# 583   brigitte liesse
# 584   gradation
# 585   propos
# 586   lumbar 64
# 587   cochrane back review
# 588   rduction des cot
# 589   population franaise
# 590   registre cochrane des lombalgie chronique
# 591   ameis a
# 592   cognitivocomportementales
# 593   programme dexercices graduel
# 594   populations
# 595   exercices discus
# 596   hyres d  usagers
# 597   gras
# 598   stern
# 599   rachis lombaire par voie foraminale
# 600   douleurs significative
# 601   consensuel
# 602   anesthsie pri 2016
# 603   effets secondaires
# 604   rev lat am enfermagem
# 605   rebro short
# 606   mathieson
# 607   hernie lombalgiques
# 608   monnin d
# 609   cohorte
# 610   sanitarias iowa
# 611   recommandations canadiennes
# 612   activement
# 613   soins douleur
# 614   lumbar radicular pain
# 615   change pain latin america advisory panel
# 616   radiofrquence trials
# 617   ulcre
# 618   tat de sant
# 619   composante radiculaire
# 620   reese
# 621   procdure invasive
# 622   american college of chargesproduits17
# 623   naissance
# 624   rugby
# 625   vocation
# 626   saintdenis dr
# 627   dpressive
# 628   magalhaes fn
# 629   vih
# 630   demoulin santefr
# 631   hydrocortancyl
# 632   beaucamps
# 633   fiche descriptive
# 634   compression nerveuse
# 635   principales
# 636   tude mlange
# 637   diagnostiques
# 638   long back review group
# 639   vibrations corps entier
# 640   pathologies articulaires
# 641   symptomatique
# 642   mesures thrapeutiques actives
# 643   cot
# 644   vargas
# 645   incomplte
# 646   examens complmentaires
# 647   limites anne
# 648   rsultat
# 649   avenue du stade
# 650   faiblesse motrice
# 651   absence de contreindication
# 652   tudes
# 653   socits
# 654   autorducation
# 655   contrle de la douleur
# 656   charge kin
# 657   risques psychosociaux
# 658   non randomiss
# 659   utilit  vise symptomatique
# 660   charge physique de travail leve
# 661   smantique
# 662   technology
# 663   incapacit  long back
# 664   dficience physique subjective
# 665   motor control pinheiro
# 666   expertise mdicale
# 667   systmatiques
# 668   semaines de traitement
# 669   bw
# 670   perte de poids
# 671   conservateur
# 672   facteurs psychosociaux
# 673   randhawa
# 674   drapeaux drapeaux jaunes
# 675   intitul
# 676   pratiques professionnelles
# 677   panagopoulos
# 678   palazzo c
# 679   thrapies psychologiques
# 680   civile
# 681   limite
# 682   cochrane central
# 683   relaxant musculaire de courte dure
# 684   programmes de essais randomiss
# 685   irradiant
# 686   fee
# 687   valuation multidisciplinaire
# 688   injury
# 689   opiodes versus placebo
# 690   atteinte motrice
# 691   volets
# 692   tian y
# 693   paris psychologie de la sant
# 694   science chronique
# 695   intradiscal
# 696   iliaques
# 697   usage
# 698   pedro de risque
# 699   indication  un traitement
# 700   corticode inject
# 701   approches
# 702   meta pain
# 703   double cochrane
# 704   imagerie toward
# 705   cmk idem
# 706   choquante
# 707   cochrane database
# 708   prsomption scientifique
# 709   walking interventions
# 710   point
# 711   jaunes bleus et noir
# 712   traitement de la douleur
# 713   psychoducation
# 714   evidence
# 715   faaompt5
# 716   pav imagerie
# 717   critre comptition
# 718   exercices en groupe
# 719   thrapeutique active
# 720   faiblesse du contrle lombo pelvien
# 721   eur spine 36
# 722   minimaux
# 723   epub
# 724   prise en charge spcifique
# 725   meta smeets
# 726   lasgue ngatif
# 727   structures d  urgences
# 728   rtrospectives
# 729   lombalgie aige ou chronique
# 730   revues systmatiques canada
# 731   ds
# 732   stratifier
# 733   rguliers
# 734   biais importants
# 735   schorr
# 736   jarvik
# 737   pain physician
# 738   autorit de sant service
# 739   coggon d
# 740   risques
# 741   anxit
# 742   start back
# 743   mj
# 744   york j
# 745   comptes rendus
# 746   tudes comparatives
# 747   anglo saxon
# 748   claudication radiculaire
# 749   Belgian Health Care Knowledge Centre
# 750   traitement usuel
# 751   cox2
# 752   socit franaise d  ostopathie
# 753   msothrapie
# 754   relatifs
# 755   changements
# 756   groupe ozone
# 757   trouble
# 758   yu
# 759   lombalgique
# 760   neto
# 761   essai randomis
# 762   inrs
# 763   appropri
# 764   traitements non pharmacologiques
# 765   facteurs de risque psychosociaux
# 766   ceintures
# 767   am enfermagem
# 768   da luz
# 769   partie imagerie
# 770   examen durgence
# 771   grandement
# 772   archives of internal medicine
# 773   valuation de la tudes
# 774   irm fonctionnelle
# 775   risque
# 776   parties prenantes
# 777   core back tool
# 778   diagnose
# 779   financiers
# 780   cage toward
# 781   excellence
# 782   umko
# 783   network of agencies for health
# 784   blue cross blue shield
# 785   risque de rcidive
# 786   troubles du comportement
# 787   Canadian Agency for drugs and technology in health
# 788   systme nerveux
# 789   disease control
# 790   c preuve 3
# 791   thrapeutiques qualit faible
# 792   inutile
# 793   trentecinq
# 794   bodyw mov
# 795   auto valuation immdiate
# 796   rectoverso
# 797   intraarticular
# 798   amed
# 799   with
# 800   valuation de la marche essais randomiss
# 801   format court
# 802   canadian agency for drugs and technology
# 803   exemple
# 804   temporaire
# 805   injury management
# 806   synthtique suggestions
# 807   musculoskeletal disorders
# 808   non lombalgie
# 809   maurel
# 810   analytique
# 811   berman bm
# 812   dougherty
# 813   diminution de la douleur
# 814   ae
# 815   jugement court
# 816   bloc de branche positif
# 817   sphinctrienne
# 818   cochrane libray
# 819   silva ir
# 820   prescrire
# 821   back risk
# 822   radioclinique
# 823   score start back  3
# 824   onset low
# 825   preuve univoque
# 826   poste de travail
# 827   paracta
# 828   communment
# 829   mineures
# 830   american college of multidisciplinaire
# 831   hcciissuebriefunrestrictedaccess tophysicaltherapypdf
# 832   lowe
# 833   discordante
# 834   nocivit has
# 835   formats
# 836   anxiety
# 837   diagnostic mdical
# 838   tomography scanning guidance
# 839   chirurgicale
# 840   association franaise
# 841   motor control
# 842   chaleur autoadministre
# 843   rtrospectifs
# 844   posture
# 845   magalhaes
# 846   viscrales
# 847   traumatologie
# 848   vs diclofnac
# 849   poppel
# 850   suivi longitudinal
# 851   accessibilit
# 852   fesse
# 853   atteinte nerveuse bilatrale
# 854   mior
# 855   lsions anatomiques
# 856   but de la stratifi
# 857   pens
# 858   chelle
# 859   meta smeets rj
# 860   presse mdicale
# 861   conseil d  tat
# 862   guidage par guidage chographique
# 863   sallis h
# 864   dysfonctions articulaires
# 865   controlled
# 866   caisse centrale
# 867   trouble postural
# 868   partie pilates
# 869   gurison
# 870   cannabis
# 871   arztebl
# 872   pelvienne
# 873   cochrane des lombalgie chronique
# 874   stratification du risque
# 875   ligamentaire
# 876   domicile
# 877   soustype de lombalgie
# 878   multicolores
# 879   dficit sensitif recherche
# 880   contentions lombaires
# 881   sfcr
# 882   lumbar disc
# 883   identifis
# 884   cochrane central register douleur  3
# 885   back risk assessment
# 886   short chenot
# 887   donnes de la littrature
# 888   health spending
# 889   cupping groupe
# 890   sci pract
# 891   headache rep
# 892   post critre principal
# 893   management GRADE
# 894   dfinition de la lombalgie
# 895   rcemment
# 896   comparant
# 897   dgnratif
# 898   cid
# 899   scientifiquement
# 900   minnesota
# 901   2ime recours
# 902   actualisation
# 903   traitement antibiotique
# 904   problmes lombaires aigus
# 905   sr
# 906   cognitivebehavioural
# 907   justement
# 908   neurostimulation
# 909   commentaire
# 910   ann intern med
# 911   ostopathique
# 912   lopes chaves e
# 913   combinaison multimodale de traitements
# 914   conditionnement has
# 915   comportements
# 916   service documentation
# 917   autoquestionnaire
# 918   anomalie
# 919   sains
# 920   infiltrations biais
# 921   personnelle
# 922   angers gnraliste
# 923   priphrisation
# 924   masseurs
# 925   college of general practitioners
# 926   muozplata
# 927   traumatisme grave
# 928   dtail
# 929   chirurgiens du rachis
# 930   complement alternat
# 931   wii
# 932   rhabilitation multidisciplinaire
# 933   fvrier
# 934   agencia de evaluacin
# 935   recommandation de consensus
# 936   accord
# 937   washington
# 938   thrapeutiques actives
# 939   prsence de drapeaux jaunes
# 940   interventions psychologiques
# 941   kinsithrapeutes
# 942   infectieuse ou inflammatoire
# 943   rcente
# 944   antcdents mdicaux de tumeur
# 945   moteurs
# 946   reponse sur une runion
# 947   straube s
# 948   mnm
# 949   sun jf
# 950   disease
# 951   affections
# 952   notice
# 953   anglais
# 954   adelaide health technology
# 955   franaise
# 956   charge adapte au risque
# 957   anne
# 958   publics
# 959   fin de tableau
# 960   mg
# 961   simplifier
# 962   bienfait
# 963   varies
# 964   large
# 965   van poppel
# 966   compterendu
# 967   mdecine d  urgence
# 968   lecteur
# 969   base de donnes medline
# 970   alternance de chaleur
# 971   omnipraticien
# 972   bases de donnes
# 973   neurologiques
# 974   cnam
# 975   avhlcd
# 976   problmatiques de scurit
# 977   factors in back
# 978   syndrome douloureux
# 979   rachidiennes chroniques
# 980   chirurgies
# 981   serein
# 982   kinsithrapie de type mdt
# 983   similaire
# 984   dprimante
# 985   problmes motionnels
# 986   kinsithrapeute
# 987   luz jnior
# 988   government
# 989   interventional
# 990   socit franaise de chirurgie orthopdique
# 991   pousse aigu
# 992   royaume care
# 993   amlioration fonctionnelle
# 994   mauvaise
# 995   menezes costa
# 996   activit physique physiques de loisirs
# 997   traitement de premire ligne
# 998   cas de contreindication
# 999   tissus

# %%
scrap(url_encoded, "infiltrations pidurales de of science")

# %%
len(medical_exist)
# Out:
# 292

# %%
import json

with open('medicalTerms_1.json') as f:
    medicalTerms_1 = json.loads(f.read())
with open('medicalTerms_2.json') as f:
    medicalTerms_2 = json.loads(f.read())
with open('medicalTerms_3.json') as f:
    medicalTerms_3 = json.loads(f.read())
with open('medicalTerms_4.json') as f:
    medicalTerms_4 = json.loads(f.read())
with open('medicalTerms_5.json') as f:
    medicalTerms_5 = json.loads(f.read())
with open('medicalTerms_6.json') as f:
    medicalTerms_6 = json.loads(f.read())
with open('medicalTerms_7.json') as f:
    medicalTerms_7 = json.loads(f.read())
with open('medicalTerms_8.json') as f:
    medicalTerms_8 = json.loads(f.read())

# %%
medicalTerms = medicalTerms_1 + medicalTerms_2 + medicalTerms_3 + medicalTerms_4 + medicalTerms_5 + medicalTerms_6 + medicalTerms_7 + medicalTerms_8

# %%
with open('medicalTerms.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(medicalTerms))

# %%
with open('medicalTerms.json') as f:
    medicalTerms = json.loads(f.read())

# %%
len(medicalTerms)
# Out:
# 3629

# %%
import pandas as pd

df = pd.DataFrame({'Medical Terms': medicalTerms, 'All Terms': allTerms[:3629]})

df.to_excel("medicalTerms VS AllTerms.xlsx")
